# %%
import json, os
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
import string
morph = MorphAnalyzer()
stops = set(stopwords.words('russian'))

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ## Данные

# %% [markdown]
# Возьмем данные вот отсюда - https://github.com/mannefedov/ru_kw_eval_datasets Там лежат 4 датасета (статьи с хабра, с Russia Today, Независимой газеты и научные статьи с Киберленинки). Датасет НГ самый маленький, поэтому возьмем его в качестве примера.

# %%
# скачаем данные в папке data и распакуем их
PATH_TO_DATA = './data'

# %%
files = [os.path.join(PATH_TO_DATA, file) for file in os.listdir(PATH_TO_DATA)]

# %% [markdown]
# Объединим файлы в один датасет.

# %%
data = pd.concat([pd.read_json(file, lines=True, encoding='utf-8') for file in files], axis=0, ignore_index=True)

# %%
data.shape
# Out:
# (1987, 5)

# %%
data.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    content  \
# 0  Многие интересуются, зачем нужна «Яблоку» молодежная фракция? Основной задачей «Молодежного «Яблока» является привлечение молодых людей к участию в выборах и деятельности партии. «Молодежное «Яблоко» работает более чем в 10 регионах. Единого руководства у нас нет, но мы стараемся координировать свою деятельность и периодически проводим акции на федеральном уровне.\nМы ведем борьбу с обязательным воинским призывом. Военный – это профессия, а не обязанность. Молодые люди вправе сами распоряжаться своей жизнью и не терять целый год, отдавая государству «долг», который они у него не занимали. По мнению одного из ведущих специалистов в области оборонной политики Алексея Арбатова, переход на контрактную армию будет стоить лишь 2% военного бюджета.\nТакже на федеральном уровне «Молодежное «Яблоко» проводило акции за освобождение политзаключенных и против вмешательства России во внутреннюю политику Украины.\nРасскажу о московских активистах. Виктору Петрунину – 19 лет, он пришел к нам боль...
# 1  Вчера «Газпром» снизил верхнюю планку прогноза собственной добычи газа в 2020 году. Через 12 лет концерн собирается добывать около 620–640 млрд. куб. м в год. При этом общее производство газа в стране, по расчетам холдинга, должно достичь 940 млрд. куб. м. Иными словами, треть добываемого объема, по мнению холдинга, должны будут обеспечить независимые производители. Эксперты не верят, что независимые компании смогут выйти на такие объемы добычи. Если расчеты «Газпрома» не оправдаются, то под ударом окажутся отечественные предприятия и население, которым придется сокращать потребление и смириться с новым витком цен. Иных путей покрытия возможного дефицита газа нет, так как вряд ли холдинг разорвет уже заключенные контракты на экспорт газа в другие страны. \n«Газпром» к 2020 году планирует добывать 620–640 млрд. куб. м газа, сообщил вчера на форуме «ТЭК России в ХХI веке» глава управления по добыче газа, газового конденсата и нефти холдинга Валерий Минликаев. Тем самым он уточнил пре...
# 2  Долголетний труд Евгения Витковского на ниве перевода, а также в качестве редактора и антологиста известен многим. Но не все знают его как поэта и прозаика. В этом году уже вышла составленная им и Еленой Кистеровой антология  «Раздол туманов: Страницы шотландской гэльской поэзии XVII–XX вв.», а в апреле запланирован выход его романа «Протей, или Византийский кризис» (отрывок из романа читайте на с. 12). С \n побеседовал \n– Одна из таких книг только что вышла – «Раздол туманов. Страницы шотландской гэльской поэзии XVII–XX веков». Это стихи 29 поэтов, все в переводе с оригинала – моем и Елены Кистеровой. Работа заняла 10 лет, включая изучение языка. Она была упоительно интересной: до нас переводов из этой поэзии на русский не было вовсе. Сейчас должен выйти том стихотворений канадского классика Роберта Уильяма Сервиса, «канадского Киплинга», около 300 стихотворений. Кроме того, в Петербурге в производстве наш огромный трехтомный плод совместной работы – антология «Франция в сердце»....
#
#                                                                                                                                                                                                                                                         keywords  \
# 0                                                                                                                                                                                                                          [яблоко, молодежь, молодежное яблоко]
# 1                                                                                                                                                                                                                                                 [газпром, газ]
# 2  [франсуа рабле, сервантес, шекспир, конан дойл, михаил булгаков, александр грин, борхес, босх, маркес, герман гессе, голландская живопись, гаргантюа и пантагрюэль, дон кихот, мастер и маргарита, москва, россия, история, поэзия, шотландия, баллада, пере]
#
#                                                                                                                                     summary  \
# 0
# 1
# 2  Евгений Витковский о том, как Босх протягивает руку Шекспиру, \r\nи оба танцуют в пламени пожара в охваченном чумой средневековом городе
#
#                                                                  title  \
# 0  "Молодежное "Яблоко": оппозиционная деятельность становится опасной
# 1                                         "Газпрома" на всех не хватит
# 2                          Бесконечная партия в четырехмерные  шахматы
#
#                                                           url
# 0  http://www.ng.ru/ng_politics/2017-04-18/11_6976_apple.html
# 1        http://www.ng.ru/economics/2008-04-03/1_gazprom.html
# 2    http://www.ng.ru/person/2018-03-22/10_927_vitkovsky.html

# %% [markdown]
# Каждой статье приписано какое-то количество ключевых слов. Допустим, что это единственно правильный набор ключевых слов (что конечно не так, но других данных у нас нет). Наша задача - придумать как извлекать точно такой же список автоматически.
# Зададим несколько метрик, по которым будем определять качество извлекаемых ключевых слов - точность, полноту, ф1-меру и меру жаккарда.

# %%
def evaluate(true_kws, predicted_kws):
    assert len(true_kws) == len(predicted_kws)
    
    precisions = []
    recalls = []
    f1s = []
    jaccards = []
    
    for i in range(len(true_kws)):
        true_kw = set(true_kws[i])
        predicted_kw = set(predicted_kws[i])
        
        tp = len(true_kw & predicted_kw)
        union = len(true_kw | predicted_kw)
        fp = len(predicted_kw - true_kw)
        fn = len(true_kw - predicted_kw)
        
        if (tp+fp) == 0:
            prec = 0
        else:
            prec = tp / (tp + fp)
        
        if (tp+fn) == 0:
            rec = 0
        else:
            rec = tp / (tp + fn)
        if (prec+rec) == 0:
            f1 = 0
        else:
            f1 = (2*(prec*rec))/(prec+rec)
            
        jac = tp / union
        
        precisions.append(prec)
        recalls.append(rec)
        f1s.append(f1)
        jaccards.append(jac)
    print('Precision - ', round(np.mean(precisions), 2))
    print('Recall - ', round(np.mean(recalls), 2))
    print('F1 - ', round(np.mean(f1s), 2))
    print('Jaccard - ', round(np.mean(jaccards), 2))

# %% [markdown]
# Проверим, что всё работает как надо.

# %%
evaluate(data['keywords'], data['keywords'])
# Out:
# Precision -  1.0
# Recall -  1.0
# F1 -  1.0
# Jaccard -  1.0

# %% [markdown]
# # Тупое решение.

# %% [markdown]
# Давайте не будем думать, а попробуем сразу придумать какое-то решение.

# %% [markdown]
# Возьмем первые 5 слов из заголовка.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:5]))
# Out:
# Precision -  0.06
# Recall -  0.05
# F1 -  0.05
# Jaccard -  0.03

# %% [markdown]
# Или 10.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:10]))
# Out:
# Precision -  0.06
# Recall -  0.06
# F1 -  0.05
# Jaccard -  0.03

# %% [markdown]
# Теперь попробуем взять самые частотные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 [x[0] for x in Counter(x.lower().split()).most_common(10)]))
# Out:
# Precision -  0.02
# Recall -  0.03
# F1 -  0.02
# Jaccard -  0.01

# %% [markdown]
# Или вообще рандомные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: 
                                                 np.random.choice(list(set(x.lower().split())), 10)))
# Out:
# Precision -  0.01
# Recall -  0.01
# F1 -  0.01
# Jaccard -  0.0

# %% [markdown]
# Теперь давайте посмотрим, что вообще извлекается.

# %%
data['title'].apply(lambda x: x.lower().split()[:10]).head(10)
# Out:
# 0                         ["молодежное, "яблоко":, оппозиционная, деятельность, становится, опасной]
# 1                                                                 ["газпрома", на, всех, не, хватит]
# 2                                                   [бесконечная, партия, в, четырехмерные, шахматы]
# 3    [экс-депутат,, осужденная, за, фальсификацию, выборов,, оказалась, членом, "боевого, братства"]
# 4                               [новая, москва, останется, территорией, экологической, безопасности]
# 5                                [f1., гран-при, сша, прошел, без, четырех, машин, и, со, «стопкой»]
# 6                                          [100, ведущих, политиков, россии, в, феврале, 2018, года]
# 7                                               [закон, "о, культуре", принимают, на, фоне, арестов]
# 8                                    [насколько, реальна, газовая, подоплека, сирийского, конфликта]
# 9                                  [фсб:, в, калужской, области, задержаны, четверо, участников, иг]
# Name: title, dtype: object

# %%
data['content'].apply(lambda x: [x[0] for x in Counter(x.lower().split()).most_common(10)]).head(10)
# Out:
# 0                                            [в, и, на, не, что, –, его, «молодежное, это, из]
# 1                                                   [в, и, на, –, млрд., куб., по, к, газа, м]
# 2                                                        [в, –, и, не, я, это, что, но, на, с]
# 3                                                    [в, на, и, ким, –, по, что, он, видео, с]
# 4                                  [в, и, на, новой, площадью, –, москвы, с, развития, парков]
# 5                                                    [в, на, и, не, с, но, уже, что, гонки, у]
# 6                                         [на, в, (с, место)., и, рф, позиции, влияние, с, по]
# 7                                               [в, и, –, по, с, не, из, культуре, будет, как]
# 8                                                     [в, и, на, с, что, для, –, по, газа, не]
# 9    [в, задержаны, рф, –, террористической, организации, области,, округа,, 2018, эмиссаром,]
# Name: content, dtype: object

# %% [markdown]
# Когда извлекаются частотные слова, то список почти полностью состоит из всяких стоп-слов. Также из-за плохой токенизации некоторые слова в обоих списках - пунктуация или слова с пунктуацией на концах. К тому же извлекаемые слова ненормализованы, а правильные ключевые слова - наоборот.

# %% [markdown]
# ## Токенизация, удаление стоп-слов и нормализация.

# %%
from string import punctuation
from nltk.corpus import stopwords
punct = punctuation+'«»—…“”*№–'
stops = set(stopwords.words('russian'))

def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0].normal_form for word in words if word and word not in stops]

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['title_norm'] = data['title'].apply(normalize)

# %%
data['title_norm'].head(10)
# Out:
# 0            [молодёжный, яблоко, оппозиционный, деятельность, становиться, опасный]
# 1                                                                 [газпром, хватить]
# 2                                      [бесконечный, партия, четырехмерный, шахматы]
# 3    [экс-депутат, осудить, фальсификация, выбор, оказаться, член, боевой, братство]
# 4                 [новый, москва, остаться, территория, экологический, безопасность]
# 5                         [f1, гран-при, сша, пройти, четыре, машина, стопка, штраф]
# 6                                [100, ведущий, политик, россия, февраль, 2018, год]
# 7                                           [закон, культура, принимать, фон, арест]
# 8                     [насколько, реальный, газовый, подоплёка, сирийский, конфликт]
# 9                       [фсб, калужский, область, задержать, четверо, участник, иго]
# Name: title_norm, dtype: object

# %% [markdown]
# Попробуем те же самые методы.

# %%
# топ 10 частотных слов статьи
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.1
# Recall -  0.21
# F1 -  0.13
# Jaccard -  0.08

# %%
evaluate(data['keywords'],data['title_norm'].apply(lambda x: x[:10]))
# Out:
# Precision -  0.13
# Recall -  0.14
# F1 -  0.12
# Jaccard -  0.07

# %% [markdown]
# Качество сильно улучшилось! Можно теперь ещё раз посмотреть, что плохого извлекается.

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                   [яблоко, молодёжный, который, год, акция, активист, это, деятельность, наш, политика]
# 1                               [миллиард, газа, год, куб, метр, газпром, добыча, который, должный, 2020]
# 2                                          [год, это, книга, роман, писать, тот, выйти, один, мир, очень]
# 3                      [ким, зинаида, видео, журналист, год, судебный, бывший, свидетель, рубль, который]
# 4                      [площадь, новый, территория, москва, га, который, тинао, парк, парковый, развитие]
# 5                                [гонка, который, команда, позиция, место, два, один, круг, из-за, пилот]
# 6               [место, влияние, рф, позиция, глава, россия, президент, политический, сергей, российский]
# 7                [культура, закон, стд, который, сфера, предложить, разработать, быть, концепция, услуга]
# 8                        [газопровод, сирия, год, турция, газа, россия, европа, катар, который, турецкий]
# 9        [организация, цос, участник, рф, террористический, задержать, центр, сообщить, говориться, 2018]
# 10                        [тихон, стихомант, это, старик, журибеда, время, казак, сэмена, говорить, отец]
# 11                    [жильё, метр, кв, год, миллион, жилищный, население, строительство, спрос, прогноз]
# 12                [российский, зритель, стать, кино, театр, год, хороший, результат, аудитория, получить]
# 13                    [революция, фестиваль, ленин, фильм, хороший, награда, миронов, делать, один, роль]
# 14               [вечер, фёдоров, книга, балашов, который, виктория, произведение, женщина, герой, елена]
# 15    [который, сирийский, переговоры, сторона, франция, резолюция, макрон, оон, президент, гуманитарный]
# 16                                   [суд, рф, кс, акционер, юкос, запрос, человек, еспч, минюст, бывший]
# 17            [электромобиль, год, тысяча, кобальт, который, компания, аккумулятор, это, автомобиль, том]
# 18                        [хороший, фильм, оскар, год, главный, один, который, стать, церемония, женщина]
# 19                   [трасса, сабина, нюрбургринг, wtcc, пилотесса, гонка, тс1, автомобиль, шмитц, также]
# Name: content_norm, dtype: object

# %% [markdown]
# Ещё остались некоторые стоп-слова. Вместо того, чтобы расширять список, давайте попробуем выкинуть несуществительные.

# %%
def normalize(text):
    
    words = [word.strip(punct) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.15
# Jaccard -  0.09

# %% [markdown]
# Ещу улучшения!

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(10)
# Out:
# 0          [яблоко, год, акция, активист, деятельность, политика, власть, человек, жизнь, выборы]
# 1               [миллиард, год, куб, газа, метр, газпром, добыча, производитель, страна, прогноз]
# 2                   [год, книга, роман, мир, жанр, стихотворение, перевод, читатель, том, россия]
# 3         [ким, зинаида, видео, год, журналист, экспертиза, свидетель, рубль, процесс, заседание]
# 4                   [площадь, москва, территория, га, тинао, парка, парк, столица, развитие, год]
# 5                  [гонка, команда, позиция, место, круг, пилот, бокс, чемпионат, заезд, дженсон]
# 6               [место, влияние, рф, позиция, глава, россия, президент, сергей, рейтинг, участие]
# 7    [культура, закон, сфера, учреждение, изменение, концепция, услуга, проект, сообщество, дело]
# 8                    [газопровод, сирия, год, турция, газа, европа, россия, катар, поток, проект]
# 9          [организация, участник, рф, центр, ячейка, эмиссар, область, сирия, деятельность, год]
# Name: content_norm, dtype: object

# %% [markdown]
# Не очень значимые слова все ещё остались. Давайте попробуем отсеять стоп-слова с помощью tfidf.

# %% [markdown]
# Воспользуемся TfidfVectorizer.

# %%
data['content_norm_str'] = data['content_norm'].apply(' '.join)

# %%
# можно заодно сделать нграммы
tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %% [markdown]
# Преобразуем наши тексты в векторы, где на позиции i стоит tfidf коэффициент слова i из словаря.

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %% [markdown]
# Отсортируем векторы текстов по этим коэффициентам и возьмем топ-10.

# %%
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-11:-1]]

# %%
keywords[:3]
# Out:
# [['яблоко',
#   'активист',
#   'акция',
#   'дарья',
#   'деятельность',
#   'молодая человек',
#   'политика',
#   'виктор',
#   'выборы',
#   'тимур'],
#  ['миллиард куб',
#   'куб метр',
#   'куб',
#   'газпром',
#   'газа',
#   'миллиард',
#   'добыча',
#   'метр',
#   'добыча газа',
#   'холдинг'],
#  ['роман',
#   'книга',
#   'жанр',
#   'стихотворение',
#   'перевод',
#   'читатель',
#   'год',
#   'поэзия',
#   'произведение',
#   'том']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# Результат ещё немного улучшился. Немного подросла точность. Теперь вместо стоп-слов в ключевые попадают имена и все такое. Иногда это хорощо, а иногда нет (собянин - может быть ключевым словом, а дарья - вряд ли)

# %% [markdown]
# Возьмем этот результат за baseline.

# %% [markdown]
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# ## Попробуем графы!

# %% [markdown]
# Большая часть методов для извлечения ключевых слов основана на применении графов. Основная идея - каким-то образом перевести текст в граф, а затем каким-то образом расчитать важность каждого узла и вывести топ-N самых важных узлов.
#
# Перевод текста в граф -  не тривиальная задача. Часто применяют такой подход - построим матрицу совстречаемости слов (в каком-то окне), эта матрица будет нашей матрицей смежности.

# %% [markdown]
# Для выбора важных узлов часто используют простой randow walk. Алгоритм примерно такой:
# 1) Каким-то образом выбирается первый узел графа (например, случайно из равномерного распределения)
# 2) на основе связей этого узла с другими, выбирается следующий узел
# 3) шаг два повторяется некоторое количество раз (например, тысячу) __*чтобы не зацикливаться, с какой-то вероятностью мы случайно перескакиваем на другой узел (даже если он никак не связан с текущим, как в шаге 1)__
# 5) на каждом шаге мы сохраняем узел в котором находимся
# 6) в конце мы считаем в каких узлах мы были чаще всего и выводим top-N
#
#
# Предполагается, что мы часто будем приходить в важные узлы графа.

# %%
from itertools import combinations

# %% [markdown]
# Для наглядности реализуем этот подход без networkx.

# %%
def get_kws(text, top=5, window_size=5, random_p=0.1):

    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    # нормализуем строки, чтобы получилась вероятность перехода
    for i in range(m.shape[0]):
        m[i] /= np.sum(m[i])
    
    # случайно выберем первое слова, а затем будет выбирать на основе полученых распределений
    # сделаем так 5 раз и добавим каждое слово в счетчик
    # чтобы не забиться в одном круге, иногда будет перескакивать на случайное слово
    
    c = Counter()
    # начнем с абсолютного случайно выбранного элемента
    n = np.random.choice(len(vocab))
    for i in range(500): # если долго считается, можно уменьшить число проходов
        
        # c вероятностью random_p 
        # перескакиваем на другой узел
        go_random = np.random.choice([0, 1], p=[1-random_p, random_p])
        if go_random:
            n = np.random.choice(len(vocab))
        
        n = take_step(n, m)
        # записываем узлы, в которых были
        c.update([n])
    
    # вернем топ-N наиболее часто встретившихся сл
    return [id2word[i] for i, count in c.most_common(top)]

def take_step(n, matrix):
    rang = len(matrix[n])
    # выбираем узел из заданного интервала, на основе распределения из матрицы совстречаемости
    next_n = np.random.choice(range(rang), p=matrix[n])
    return next_n

# %%
# %%time
keywords_rw = data['content_norm'].apply(lambda x: get_kws(x, 10, 10))
# Out:
# Wall time: 5min 32s

# %%
evaluate(data['keywords'], keywords_rw)
# Out:
# Precision -  0.11
# Recall -  0.21
# F1 -  0.14
# Jaccard -  0.08

# %%
keywords_rw.head(10)
# Out:
# 0         [яблоко, активист, год, уровень, деятельность, акция, кампания, поддержка, ситуация, форма]
# 1                   [миллиард, газпром, газа, метр, год, добыча, куб, холдинг, производитель, страна]
# 2                    [год, рецензия, мир, жанр, редактор, мениппея, книга, проблема, страница, роман]
# 3            [журналист, видео, год, суд, участок, экспертиза, судья, защитник, владивосток, процесс]
# 4                        [территория, га, площадь, тинао, развитие, год, москва, парк, власть, парка]
# 5                    [гонка, позиция, заезд, чемпионат, победа, бокс, резина, вернь, круг, лидерство]
# 6          [влияние, позиция, место, рф, глава, операция, исследование, представитель, россия, визит]
# 7          [культура, закон, сфера, проект, внесение, концепция, июль, услуга, изменение, разработка]
# 8                         [сирия, газопровод, россия, катар, европа, год, турция, союз, поток, рынок]
# 9    [участник, организация, рф, ячейка, подготовка, житель, прошедшее, территория, связь, сообщение]
# Name: content_norm, dtype: object

# %% [markdown]
# Попбруем теперь важность считать с помощью какой-нибудь метрики из networkx.

# %%
import networkx as nx

# %%
def build_matrix(text, window_size=5):
    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был ненаправленный 
            m[j][k] += 1
            m[k][j] += 1
    
    return m, id2word, word2id

def some_centrality_measure(text, window_size=5, topn=5):
    
    matrix, id2word, word2id = build_matrix(text, window_size)
    G = nx.from_numpy_array(matrix)
    # тут можно поставить любую метрику
    node2measure = dict(nx.degree(G))
    
    return [id2word[index] for index,measure in sorted(node2measure.items(), key=lambda x: -x[1])[:topn]]

# %%
# %%time
keyword_nx = data['content_norm'].apply(lambda x: some_centrality_measure(x, 10, 10))
# Out:
# Wall time: 1min 19s

# %%
evaluate(data['keywords'], keyword_nx)
# Out:
# Precision -  0.13
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09

# %% [markdown]
# Результаты не превосходят tfidf, но и не сильно уступают. Явно можно что-то доработать и превзойти baseline.

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# В семинаре установлен такой бейзлан - F1 -  0.16 (не будем учитывать точность и полноту по отдельности и отбросим жаккара).

# %% [markdown]
# **Ваша задача - предложить 3 способа побить бейзлайн. **

# %% [markdown]
# Нет никаких ограничений кроме:
#
# 1) нельзя изменять метрику
# 2) решение должно быть воспроизводимым

# %% [markdown]
# В качестве ответа нужно предоставить jupyter тетрадку с экспериментами (обязательное условие!) и описать каждую из идей в форме - https://goo.gl/forms/H9lBH9wCxqq1T0ru2

# %% [markdown]
# Каждый реализованный и описанный способ оценивается в 3 балла. Дополнительный балл можно получить, если способы затрагивают разные аспекты решения (например, первая идея - улучшить нормализацию, вторая - улучшить способ представления текста в виде графа, третья - предложить способ удаления из топа идентичных ключевых слов (рф, россия)).

# %% [markdown]
# Можно использовать мой код как основу, а можно придумать что-то полностью другой.

# %% [markdown]
# Если у вас никак не получается побить бейзлайн вы можете предоставить реализацию и описание неудавшихся экспериментов (каждый оценивается в 0.5 баллов).

# %% [markdown]
# ## 1. Удяляем имена

# %%
def normalize(input_text, del_stopwords=True, del_digit=True):
    
    words = [x.lower().strip(string.punctuation+'»«–…') for x in word_tokenize(input_text)]
    words = [morph.parse(x)[0] for x in words if x]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN' and ('Name' not in word.tag)] #удалим личные имена

    lemmas = []
    for lemma in words:
        if del_stopwords:
            if lemma in stops:
                continue
        if del_digit:
            if lemma.isdigit():
                continue
        lemmas.append(lemma)
        
    return lemmas

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['content_norm_str'] = data['content_norm'].apply(' '.join)

# %%
tfidf = TfidfVectorizer(ngram_range=(1,1), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}
texts_vectors = tfidf.transform(data['content_norm_str'])
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]] 
keywords[:3]
# Out:
# [['яблоко', 'активист', 'акция', 'деятельность', 'молодая человек'],
#  ['миллиард куб', 'куб метр', 'куб', 'газпром', 'газа'],
#  ['книга', 'жанр', 'роман', 'стихотворение', 'читатель']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.19
# Recall -  0.18
# F1 -  0.17
# Jaccard -  0.11

# %% [markdown]
# ##### Стало чуть лучше!

# %% [markdown]
# ## 2. Добавим загаловки

# %%
data['title_norm'] = data['title'].apply(normalize)

# %%
data['title_norm_str'] = data['title_norm'].apply(' '.join)

# %%
for i, t in enumerate(keywords):
    keywords[i] = list(set(keywords[i] + data['title_norm'][i]))

# %%
keywords[:3]
# Out:
# [['молодая человек', 'деятельность', 'активист', 'акция', 'яблоко'],
#  ['газпром', 'миллиард куб', 'куб метр', 'газа', 'куб'],
#  ['партия', 'книга', 'шахматы', 'читатель', 'жанр', 'роман', 'стихотворение']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.17
# Recall -  0.24
# F1 -  0.19
# Jaccard -  0.11

# %% [markdown]
# ##### Еще чуть лучше!

# %% [markdown]
# ## 3. Готовые методы

# %% [markdown]
# ### Gensim TextRank

# %%
from gensim.summarization import keywords

# %%
def kw(text):
    return keywords(text, split=True, pos_filter=())[:10]

# %%
kwords = data['content_norm_str'].apply(kw)

# %%
evaluate(data['keywords'], kwords)
# Out:
# Precision -  0.07
# Recall -  0.11
# F1 -  0.08
# Jaccard -  0.04

# %% [markdown]
# ##### Очень плохо :(

# %%
kwords
# Out:
# 0          [яблоко, жизнь год, политика, акция уровень борьба, украина активист, власть, россия, молодая человек участие выборы деятельность партия, проблема, позиция]
# 1                     [газпром, миллиард, прогноз добыча газа год, страна, метр, производитель эксперт, расчет холдинг, цена, объем, предприятие население потребление]
# 2                                                             [год, книга, роман, читатель, мир, герои, произведение, жанр мениппея, работа, перевод качество редактор]
# 3                                                                      [журналист видео, летие, год, заседание, свидетель, процесс, дело, судья экспертиза, рубль, суд]
# 4                                                  [площадь, территория, парк, парка, москва мегаполис, тинао регион, год столица, развитие, власть новое, департамент]
# 5                                                          [гонка участие, команда, балл позиция, круг, бокс, заезд, место нико, этап чемпионат, победа, пилот строчка]
# 6       [влияние глава, место фон, позиция политик февраль гонка, россия форум, президент, сообщение участие, институт, эксперт политолог, исследование, реитинг путин]
# 7                                          [культура, первое концепция проект закон, дело, сообщество, сфера, изменение акт срок, законодательство, год, система, учет]
# 8                                       [сирия, газа, турция европа газопровод поток, россия, год идея, проект, газ катар иран, строительство, месторождение, поставка]
# 9                                                                                                                            [сирия сообщение, организация государство]
# 10                                                                    [стихомант, старик, сэмена журибеда окно, дежнев казак, время, отец, человек, голос, поезд, друг]
# 11                           [жилье прогноз, год, миллион метр, спрос, плутник, объем строительство, предложение, недвижимость, минстрои, рост доход население эксперт]
# 12                                    [зритель, год, театр ленсовет, фонд кино результат исследование аудитория, фильм, связь, табаков, мера, премия, режиссер бутусов]
# 13                          [фестиваль фильм, награда, воина ленин, миронов, революция телеэкран, зритель, остров сахалин, сериал, роль артист, кинематографист период]
# 14                          [вечер, федоров, книга, произведение женщина мужчина, писательница виктория балашов, писатель, литература, жизнь, человек страна, чистяков]
# 15                                     [макрон, президент, сторона, сирия переговоры, резолюция, россия, москва франция, оон прекращение, урегулирование, кризис париж]
# 16                                                                                                          [минюст, постановление суд, еспч, решение, запрос, человек]
# 17           [рынок электромобиль, компания, исследование агентство год продажа, автомобиль электрокар, кобальт, цена, россия, батарея, бензин, технология аккумулятор]
# 18                                                               [итог фильм, церемония, актер, статуэтка, приз, торо год, роль, мужчина женщина рыба, речь, номинация]
# 19                                                                                          [трасса, гонка нюрбургринг, автомобиль, пилотесса, участие, женщина, число]
# 20                                                                   [книга, литература, перевод, год россия франция, язык, творчество, серия, салон, институт, поэзия]
# 21                                           [воина, формирование, раион сирия, москва дамаск, армия, воиско, военныи, вашингтон сила поддержка, территория, ополчение]
# 22                                                                                [шельф, год, граница, страна, человек точка полюс, мир, зона, сторона, километр, лед]
# 23                                                                                     [поэт, мир метр, март центр, имя, встреча, клуб, дом, книга, пряхин, библиотека]
# 24                                              [авиакомпания, лоукостер, победа, багаж, пассажир ограничение, тариф, ространснадзор, полет, питание борт, обеспечение]
# 25                                                        [серебряков, культура, сухарев фильм, россия, идея, актер число, пожигаило, человек, развитие история, совет]
# 26                                            [температура глубина, источник тепло земля, система, энергия, скважина, часть, страна, теплов, россия, горячее вода пара]
# 27                                                                  [власть, собчак, электорат, система фигура, время, проект, путин оппозиция, интерес, партия, часть]
# 28                                                                                [путин, день, встреча, буш, делегация саммит, россия, президент, город, место, гость]
# 29                                                                    [сальери первое, моцарт, человек, результат, бог, зависть вид, мир, опыт, пушкин, гении соперник]
#                                                                                      ...
# 1957                                 [турция анкара, беженец, миллиард евро, европа брюссель, мигрант сирия территория, тысяча, год, законодательство, сторона, сделка]
# 1958                                                              [страх, огнемет, маск, устроиство, система, мозг, человек дело, волос тело, компания фирма, организм]
# 1959                                      [олимпиада, государство, спортсмен игра пхенчхан флаг гимн, страна, комитет россия, депутат, власть, путин, год, выступление]
# 1960                                                                                                                         [год, премия текст, нонконформизм, формат]
# 1961                                                    [страна, союзник сша, вооружение, россия, регион, год, оружие, санкция, сделка поставка система, вашингтон мир]
# 1962                                                                                                                     [препарат, министр, миллиард, мера, президент]
# 1963                                                                    [развитие шахматы, партнер, год, новосибирск, город, работа, бизнес, холдинг ратм, вид, россия]
# 1964    [стратегия безопасность, развитие, год документ, среда, выброс атмосфера газ, уровень цель, оон изменение климат, мера, вызов угроза, деятельность последствие]
# 1965                                        [строительство, год, канал, россия проект эколог, территория заповедник, раион, море, медведев обращение, автодорога, союз]
# 1966                                                                                                                                 [рил жига, век время царствование]
# 1967                                                                    [гонка, позиция старт, роба, пилот хонда, квалификация, пелетон, проблема, борьба, лопес, сход]
# 1968                                                     [мир гонконг, китаи, экономика, бизнес, решение власть, население, год состав кнр, вопрос, транспорт, условие]
# 1969                                                         [россия, человек статус беженец, год, украинец, буртина, закон, украина власть помощь, родина, слово, имя]
# 1970                                                         [пациент, год, работа, стратегия развитие здравоохранение, сообщество, врач, мэр, москва, практика, медик]
# 1971                                                                [год, режиссер, бердо гервиг, номинация, фильм участие, право, фон, картина, женщина кино, актриса]
# 1972                                                                                           [ребенок, имя, мир, молодежь, год, вопрос, время, кит, диалог, конфликт]
# 1973                                                                [стих рассказ, тишина, книга, автор шенкман поэт, буним, ребенок, журнал, холод, анекдот, читатель]
# 1974                   [год, самолет, метр, энергия технология, эксплуатация здание, лидер движение энергетика, батарея, школа лозанна институт, потребление, снижение]
# 1975                      [кандидат президент, женщина, грузия цулукиани, саакашвили объединение, выбор октябрь, мид зурабишвили, призыв, маргвелашвили, министр, пост]
# 1976                                           [клетка, антиген, год, железо, процесс фагоцитоз, человек, комплекс, мечник премия, испытание миллион, помощь микроскоп]
# 1977                                                                                    [музыка, тургенев, барбие, год, биограф, время, книга, жизнь, век, современник]
# 1978                                            [бизнесмен абхазия, грузия, москва стратегия, багапш россия, тбилиси, отношение республика, сторона, шаг, розыск, боев]
# 1979                                                             [китаи, партия, срок, решение, эксперт, путин, экономика система, общество, страна режим, конец жизнь]
# 1980                                                    [год, проект, панель, страна, энергия, решение россия, растение, мощность, директор компания, утилизация отход]
# 1981                                    [художник, работа серия выставка, жизнь, бурлюк, произведение, искусство, метр подход, егоров, пощечина, колеичук документация]
# 1982                                                        [год, эстония, латвия, миллиард доллар, республика, оккупация, ущерб, украина власть страна, литва, убыток]
# 1983                                            [книга, человек рукопись, закон, голова, годовщина год, огонь, костер тщеславие, пушкин тема, правитель, дуэль история]
# 1984                                                           [сша, теракт, вашингтон, гражданин, королевство, угроза регион, человек, мусульманин, террорист, данные]
# 1985                                         [воина патриарх, россия, роль церковь, решение, глава рпц болгария, государство, вопрос, президент, военныи, идентичность]
# 1986                                            [балет, театр, петербург, спектакль, петипа хореограф танцовщик, россия, год день, зритель время публика, яковлев, зал]
# Name: content_norm_str, Length: 1987, dtype: object

# %% [markdown]
# ### RAKE

# %%
from rake_nltk import Rake

# %%
r = Rake(stops)

def rake_keywords(text):
    r.extract_keywords_from_text(text)
    return r.get_ranked_phrases()

# %%
kwords = data['content_norm_str'].apply(rake_keywords)

# %%
evaluate(data['keywords'], kwords)
# Out:
# Precision -  0.0
# Recall -  0.0
# F1 -  0.0
# Jaccard -  0.0

# %% [markdown]
# ##### Вообще по нулям :(

# %% [markdown]
# ## 4. Изменим метрику важности для узлов графа

# %%
vectors = texts_vectors.toarray()
vocab = tfidf.vocabulary_

# %%
def some_centrality_measure(text, i, window_size=5, topn=5):
    
    matrix, id2word, word2id = build_matrix(text, window_size)
    G = nx.from_numpy_array(matrix)
    # тут можно поставить любую метрику
    node2measure = dict(nx.degree(G))
    for key in node2measure.keys():
        try:
            n = vocab[id2word[key]]
            tfidf = vectors[i][n]
            
        except:
            tfidf = 0
        #print(node2measure[key], key, tfidf)
        node2measure[key] *= tfidf
        
    return [id2word[index] for index,measure in sorted(node2measure.items(), key=lambda x: -x[1])[:topn]]

# %%
keywords_gr = list()
for i, text in enumerate(data['content_norm']):
    keywords_gr.append(some_centrality_measure(text, i))

# %%
keywords_gr
# Out:
# [['яблоко', 'акция', 'активист', 'деятельность', 'год'],
#  ['газпром', 'газа', 'куб', 'миллиард', 'добыча'],
#  ['книга', 'год', 'читатель', 'перевод', 'жанр'],
#  ['видео', 'журналист', 'экспертиза', 'свидетель', 'суд'],
#  ['га', 'площадь', 'москва', 'территория', 'парка'],
#  ['гонка', 'команда', 'позиция', 'бокс', 'круг'],
#  ['место', 'влияние', 'рф', 'позиция', 'глава'],
#  ['культура', 'закон', 'сфера', 'учреждение', 'концепция'],
#  ['газопровод', 'сирия', 'катар', 'турция', 'газа'],
#  ['участник', 'организация', 'рф', 'ячейка', 'исламист'],
#  ['старик', 'казак', 'подушка', 'отец', 'мираж'],
#  ['жильё', 'метр', 'население', 'спрос', 'миллион'],
#  ['кино', 'зритель', 'театр', 'аудитория', 'ленсовет'],
#  ['фестиваль', 'революция', 'ленин', 'фильм', 'награда'],
#  ['фёдоров', 'вечер', 'виктория', 'женщина', 'книга'],
#  ['макрон', 'резолюция', 'переговоры', 'франция', 'оон'],
#  ['еспч', 'минюст', 'суд', 'акционер', 'рф'],
#  ['электромобиль', 'год', 'аккумулятор', 'автомобиль', 'тысяча'],
#  ['фильм', 'статуэтка', 'церемония', 'женщина', 'актёр'],
#  ['трасса', 'автомобиль', 'гонка', 'участие', 'петля'],
#  ['книга', 'перевод', 'литература', 'франция', 'год'],
#  ['сирия', 'дамаск', 'формирование', 'вашингтон', 'армия'],
#  ['шельф', 'точка', 'полюс', 'год', 'хребет'],
#  ['метр', 'поэт', 'библиотека', 'март', 'центр'],
#  ['пассажир', 'авиакомпания', 'багаж', 'победа', 'тариф'],
#  ['серебряков', 'фильм', 'культура', 'идея', 'актёр'],
#  ['температура', 'тепло', 'теплов', 'скважина', 'энергия'],
#  ['собчак', 'власть', 'электорат', 'система', 'фигура'],
#  ['саммит', 'путин', 'буш', 'встреча', 'саванна'],
#  ['моцарт', 'зависть', 'гений', 'музыка', 'человек'],
#  ['сирия', 'группировка', 'иерусалим', 'дамаск', 'страна'],
#  ['мо', 'управление', 'пентагон', 'закупка', 'военный'],
#  ['предмет', 'наука', 'украина', 'программа', 'химия'],
#  ['система', 'водохранилище', 'река', 'метр', 'путь'],
#  ['стих', 'поэтесса', 'поэт', 'журнал', 'поэзия'],
#  ['наблюдатель', 'венедиктов', 'голосование', 'выборы', 'выбор'],
#  ['снег', 'метель', 'кошка', 'ветер', 'призрак'],
#  ['университет', 'рейтинг', 'вуз', 'предмет', 'ректор'],
#  ['год', 'теракт', 'метро', 'суд', 'полиция'],
#  ['крым', 'закон', 'суд', 'реабилитация', 'бобров'],
#  ['экранизация', 'герой', 'революция', 'мука', 'выбор'],
#  ['технология', 'русало', 'производство', 'экология', 'компания'],
#  ['оргкомитет', 'сочи', 'программа', 'олимпиада', 'хоккей'],
#  ['дерево', 'кустарник', 'тысяча', 'двор', 'год'],
#  ['книга', 'метр', 'поэт', 'стих', 'мандельштам'],
#  ['марс', 'маск', 'маска', 'земля', 'база'],
#  ['фсб', 'суд', 'приказ', 'ключ', 'мессенджер'],
#  ['рособрнадзор', 'образование', 'минобрнаука', 'мониторинг', 'коллегия'],
#  ['заявление', 'теракт', 'испания', 'ирак', 'бригада'],
#  ['нарушение', 'выборы', 'путин', 'голосование', 'москва'],
#  ['корбина', 'дело', 'путин', 'лейборист', 'выдержка'],
#  ['сша', 'россия', 'вашингтон', 'оружие', 'путин'],
#  ['власть', 'народ', 'конституция', 'ельцин', 'федерация'],
#  ['украина', 'институт', 'период', 'год', 'ссср'],
#  ['байкал', 'озеро', 'акция', 'год', 'минута'],
#  ['мексика', 'вмешательство', 'выбор', 'россия', 'обвинение'],
#  ['книга', 'стих', 'пастернак', 'автор', 'поэт'],
#  ['фильм', 'статуэтка', 'церемония', 'женщина', 'актёр'],
#  ['пакистан', 'проект', 'афганистан', 'газопровод', 'строительство'],
#  ['олимпиада', 'школьник', 'область', 'призёр', 'победитель'],
#  ['клетка', 'железо', 'процесс', 'испытание', 'премия'],
#  ['рейс', 'авиакомпания', 'угроза', 'самолёт', 'безопасность'],
#  ['выброс', 'год', 'газа', 'планет', 'рост'],
#  ['самолёт', 'аэропорт', 'татарстан', 'катастрофа', 'казань'],
#  ['сущность', 'власть', 'государство', 'год', 'человек'],
#  ['культура', 'книга', 'человек', 'чтение', 'информация'],
#  ['сон', 'поэтесса', 'книга', 'читатель', 'поэт'],
#  ['герой', 'книга', 'автор', 'магдалинов', 'антиутопия'],
#  ['год', 'рождаемость', 'коэффициент', 'ребёнок', 'число'],
#  ['ссср', 'москва', 'учреждение', 'список', 'помета'],
#  ['наблюдатель', 'москва', 'голосование', 'участок', 'столица'],
#  ['концерн', 'компания', 'проект', 'бизнес', 'нефть'],
#  ['родитель', 'школа', 'учитель', 'ребёнок', 'задание'],
#  ['бог', 'стихотворение', 'поэт', 'человек', 'поэзия'],
#  ['негр', 'внешность', 'раб', 'россия', 'лицо'],
#  ['пакистан', 'проект', 'газопровод', 'строительство', 'афганистан'],
#  ['протест', 'акция', 'оппозиция', 'май', 'инаугурация'],
#  ['миллиард', 'год', 'доллар', 'боев', 'ввс'],
#  ['сочи', 'олимпиада', 'строительство', 'миллиард', 'минтранс'],
#  ['год', 'регион', 'подмосковье', 'тысяча', 'область'],
#  ['соотечественник', 'программа', 'рф', 'переселение', 'справка'],
#  ['конкурс', 'финалист', 'структура', 'путин', 'просьба'],
#  ['эко', 'жизнь', 'человек', 'бог', 'атеист'],
#  ['пользователь', 'портал', 'проект', 'голосование', 'гражданин'],
#  ['папа', 'кардинал', 'епископ', 'ватикан', 'год'],
#  ['поставка', 'экспорт', 'нефть', 'год', 'газа'],
#  ['пропуск', 'машина', 'охранник', 'этаж', 'дед'],
#  ['князь', 'русь', 'время', 'жена', 'сын'],
#  ['опека', 'нефть', 'цена', 'рынок', 'добыча'],
#  ['занятие', 'курс', 'центр', 'секция', 'язык'],
#  ['абхазия', 'съезд', 'доброволец', 'война', 'организация'],
#  ['регулирование', 'выброс', 'квота', 'налог', 'страна'],
#  ['год', 'электроэнергетика', 'энергетика', 'электроэнергия', 'энергия'],
#  ['вещество', 'новичок', 'год', 'кгб', 'россия'],
#  ['отец', 'княжество', 'престол', 'башня', 'сын'],
#  ['застройщик', 'объект', 'квартира', 'собянин', 'власть'],
#  ['румыния', 'молдова', 'автономия', 'объединение', 'молдавия'],
#  ['египет', 'аэс', 'росатом', 'реактор', 'энергоблок'],
#  ['церковь', 'иерусалим', 'налог', 'мэрия', 'земля'],
#  ['россия', 'великобритания', 'королевство', 'ответ', 'дипломат'],
#  ['флот', 'авария', 'сша', 'авианосец', 'борт'],
#  ['фестиваль', 'революция', 'ленин', 'фильм', 'награда'],
#  ['бригада', 'ополчение', 'сила', 'войско', 'оборона'],
#  ['мама', 'тусовка', 'тётя', 'девушка', 'губа'],
#  ['кредитор', 'ципраса', 'греция', 'грек', 'юнкер'],
#  ['сирия', 'дамаск', 'вашингтон', 'ополчение', 'союзник'],
#  ['рождаемость', 'интернет', 'секс', 'россиянин', 'автомобиль'],
#  ['общество', 'страна', 'травма', 'развитие', 'россия'],
#  ['галстук', 'оппозиция', 'резиденция', 'саакашвили', 'акция'],
#  ['врач', 'кабинет', 'поликлиника', 'пациент', 'практика'],
#  ['препарат', 'миллиард', 'министр', 'вентиляция', 'минздрав'],
#  ['финляндия', 'сборная', 'команда', 'матч', 'латвия'],
#  ['чёрный', 'праздник', 'поэзия', 'стих', 'поэт'],
#  ['книга', 'писатель', 'жизнь', 'отрыв', 'воспоминание'],
#  ['сотрудничество', 'опера', 'год', 'обмен', 'культура'],
#  ['месторождение', 'газпром', 'конкурс', 'лицензия', 'компания'],
#  ['герой', 'феникс', 'фильм', 'сцена', 'воспоминание'],
#  ['синай', 'рф', 'часы', 'самолёт', 'совещание'],
#  ['путин', 'россия', 'власть', 'разделение', 'государство'],
#  ['отход', 'россия', 'регион', 'захоронение', 'сотрудничество'],
#  ['дамаск', 'сирия', 'территория', 'турция', 'коалиция'],
#  ['кокаин', 'колумбия', 'килограмм', 'наркотик', 'страна'],
#  ['грузия', 'абхазия', 'россия', 'нато', 'сторона'],
#  ['аккаунт', 'соцсеть', 'страница', 'объявление', 'законодатель'],
#  ['мусор', 'завод', 'отход', 'диоксид', 'сжигание'],
#  ['биосфера', 'вид', 'планета', 'человек', 'вымирание'],
#  ['представитель', 'палата', 'конгрессмен', 'масло', 'сенатор'],
#  ['суд', 'журналистка', 'слушатель', 'дело', 'арест'],
#  ['климат', 'изменение', 'планета', 'ураган', 'потепление'],
#  ['женщина', 'вождение', 'право', 'распоряжение', 'машина'],
#  ['армия', 'румыния', 'нато', 'молдавия', 'республика'],
#  ['соглашение', 'сша', 'торговля', 'год', 'закон'],
#  ['ливия', 'кампания', 'евро', 'дело', 'париж'],
#  ['человек', 'интеллект', 'тело', 'боль', 'мозг'],
#  ['студент', 'мгу', 'футбол', 'чемпионат', 'команда'],
#  ['доказательство', 'фсб', 'россия', 'министр', 'атака'],
#  ['законопроект', 'украина', 'нато', 'оборона', 'главнокомандующий'],
#  ['россия', 'санкция', 'сша', 'оружие', 'лавров'],
#  ['стих', 'тишина', 'шенкман', 'рассказ', 'буним'],
#  ['крокодил', 'речушка', 'берег', 'бассейн', 'вода'],
#  ['церковь', 'иерусалим', 'гроб', 'паломник', 'мэрия'],
#  ['руководитель', 'школа', 'ребёнок', 'родитель', 'класс'],
#  ['выбор', 'выборы', 'сотрудник', 'работодатель', 'предприниматель'],
#  ['улитка', 'жизнь', 'поэзия', 'время', 'часть'],
#  ['иностранец', 'икра', 'пример', 'ракета', 'комиссия'],
#  ['вертолёт', 'машина', 'оборудование', 'россия', 'партия'],
#  ['лошадь', 'ди', 'россиянин', 'житель', 'мороз'],
#  ['книга', 'поляков', 'стихотворение', 'стих', 'давыдов'],
#  ['команда', 'гонка', 'нико', 'мерседес', 'победа'],
#  ['япония', 'год', 'страна', 'правление', 'премьер'],
#  ['пакет', 'яров', 'оператор', 'закон', 'власть'],
#  ['польша', 'закон', 'холокост', 'еврей', 'дуда'],
#  ['улица', 'площадь', 'музей', 'программа', 'кольцо'],
#  ['пилот', 'команда', 'гонка', 'росберг', 'машина'],
#  ['митинг', 'журналист', 'москва', 'человек', 'крым'],
#  ['ходорковский', 'сми', 'власть', 'проект', 'медиа'],
#  ['пас', 'ассамблея', 'кавказ', 'делегация', 'поездка'],
#  ['экспедиция', 'право', 'проба', 'недра', 'арктика'],
#  ['тайфун', 'шанхай', 'сентябрь', 'дождь', 'китай'],
#  ['экономика', 'цб', 'инфляция', 'минэкономразвития', 'ведомство'],
#  ['росатом', 'египет', 'контракт', 'станция', 'эль'],
#  ['епархия', 'приход', 'священник', 'церковь', 'прихожанин'],
#  ['спектакль', 'постановка', 'театр', 'фестиваль', 'ребёнок'],
#  ['ер', 'партия', 'путин', 'медведев', 'власть'],
#  ['еспч', 'компенсация', 'юкос', 'выплата', 'конституция'],
#  ['университет', 'церковь', 'храм', 'вуз', 'патриарх'],
#  ['мо', 'управление', 'пентагон', 'закупка', 'военный'],
#  ['пресс', 'президент', 'фильм', 'трамп', 'пресса'],
#  ['участок', 'голосование', 'область', 'выбор', 'россия'],
#  ['регистрация', 'володин', 'госдума', 'депутат', 'место'],
#  ['грузия', 'мэрия', 'акция', 'тбилиси', 'мвд'],
#  ['закон', 'язык', 'украина', 'год', 'киев'],
#  ['опека', 'добыча', 'нефтедобыча', 'сокращение', 'картель'],
#  ['комиссаров', 'депутат', 'журналист', 'стол', 'комитет'],
#  ['поход', 'муза', 'странствие', 'километр', 'ребята'],
#  ['россия', 'год', 'полиция', 'скрипаль', 'полковник'],
#  ['кандидат', 'подпись', 'горбунов', 'выбор', 'видеонаблюдение'],
#  ['авианосец', 'шторм', 'базирование', 'комплекс', 'строительство'],
#  ['завод', 'брест', 'производство', 'строительство', 'свинец'],
#  ['нация', 'народ', 'население', 'идентичность', 'национальность'],
#  ['юнеско', 'трасса', 'заповедник', 'строительство', 'эколог'],
#  ['явка', 'медведев', 'голос', 'зюганов', 'избиратель'],
#  ['птица', 'дед', 'супермаркет', 'банка', 'небо'],
#  ['подружка', 'николай', 'берег', 'язык', 'вода'],
#  ['образование', 'госпрограмма', 'система', 'подготовка', 'рф'],
#  ['беляков', 'средство', 'препарат', 'законопроект', 'исследование'],
#  ['создатель', 'художник', 'выставка', 'творчество', 'бэкграунд'],
#  ['компания', 'стенд', 'выставка', 'система', 'аппарат'],
#  ['криптовалюта', 'венесуэла', 'нефть', 'сша', 'энергоресурсы'],
#  ['приднестровье', 'оружие', 'армия', 'молдова', 'вооружение'],
#  ['миротворец', 'украина', 'беларусь', 'белоруссия', 'минск'],
#  ['колония', 'заключённый', 'женщина', 'ребёнок', 'наказание'],
#  ['песнь', 'книга', 'диссидент', 'человек', 'песня'],
#  ['год', 'мощность', 'ветроэнергетика', 'ветроустановка', 'миллиард'],
#  ['фильм', 'драма', 'целое', 'история', 'актёр'],
#  ['иго', 'нефть', 'террорист', 'территория', 'объект'],
#  ['гута', 'джейша', 'пригород', 'дамаск', 'прекращение'],
#  ['германия', 'храм', 'ислам', 'епархия', 'член'],
#  ['вид', 'миллион', 'биосфера', 'биоразнообразие', 'животное'],
#  ['рассмотрение', 'понедельник', 'узбекистан', 'обращение', 'учёт'],
#  ['администрирование', 'взнос', 'год', 'налог', 'рубль'],
#  ['лукашенко', 'встреча', 'патриарх', 'папа', 'белоруссия'],
#  ['кндр', 'корея', 'пхеньян', 'сша', 'вашингтон'],
#  ['террорист', 'израиль', 'год', 'араб', 'семья'],
#  ['путин', 'газета', 'выбор', 'явка', 'россия'],
#  ['власть', 'отравление', 'россия', 'конъюнктура', 'запад'],
#  ['книжка', 'таллин', 'рыцарь', 'задание', 'город'],
#  ['безопасность', 'доклад', 'нато', 'ситуация', 'военный'],
#  ['самолёт', 'турция', 'действие', 'экипаж', 'территория'],
#  ['миркина', 'философ', 'вечер', 'мыслитель', 'год'],
#  ['пушкин', 'читатель', 'книга', 'место', 'поэт'],
#  ['собчак', 'крым', 'штаб', 'тверь', 'заявление'],
#  ['военный', 'сбор', 'мужчина', 'лукашенко', 'информация'],
#  ['гудков', 'партия', 'собчак', 'яблоко', 'явлинский'],
#  ['клетка', 'нейрон', 'вода', 'матрица', 'титан'],
#  ['путин', 'электорат', 'выбор', 'избиратель', 'власть'],
#  ['нация', 'народ', 'население', 'идентичность', 'национальность'],
#  ['доллар', 'рубль', 'цена', 'нефть', 'греция'],
#  ['индия', 'пакистан', 'сша', 'вашингтон', 'россия'],
#  ['человек', 'рассуждение', 'вопрос', 'представление', 'реакция'],
#  ['произвол', 'конкурс', 'год', 'милиция', 'право'],
#  ['афганистан', 'талибан', 'провинция', 'талиб', 'год'],
#  ['эко', 'многоточие', 'рыцарь', 'жизнь', 'литр'],
#  ['словарь', 'авторство', 'автор', 'тысяча', 'пользователь'],
#  ['доминика', 'кофе', 'клиент', 'отпуск', 'собес'],
#  ['энергетика', 'трансформация', 'год', 'компания', 'проект'],
#  ['мусульманин', 'экстремизм', 'заключённый', 'зэк', 'ведомство'],
#  ['существо', 'цивилизация', 'интеллект', 'инженерия', 'вид'],
#  ['дагестан', 'республика', 'ваххабит', 'год', 'чечня'],
#  ['комиссия', 'представитель', 'работа', 'мак', 'транспорт'],
#  ['год', 'теракт', 'метро', 'суд', 'полиция'],
#  ['центрполиграф', 'метр', 'литература', 'детектив', 'стих'],
#  ['гонка', 'круг', 'трасса', 'роба', 'позиция'],
#  ['турция', 'грузия', 'тбилиси', 'анкара', 'территория'],
#  ['заседание', 'энергетика', 'азербайджан', 'турция', 'министр'],
#  ['церемония', 'игра', 'сочи', 'закрытие', 'чернышенко'],
#  ['газа', 'газопровод', 'метр', 'куб', 'миллиард'],
#  ['савченко', 'рада', 'надежда', 'луценко', 'брифинг'],
#  ['книга', 'год', 'читатель', 'перевод', 'жанр'],
#  ['бек', 'литература', 'встреча', 'год', 'книга'],
#  ['пользователь', 'карта', 'фонд', 'деньга', 'возмещение'],
#  ['кандидат', 'выборы', 'подпись', 'избирком', 'выбор'],
#  ['хокинг', 'год', 'жизнь', 'ньютон', 'вселенная'],
#  ['собчак', 'пожар', 'дом', 'ребёнок', 'чп'],
#  ['дождь', 'город', 'житель', 'жизнь', 'германия'],
#  ['савченко', 'допрос', 'заседание', 'страсбург', 'киев'],
#  ['украина', 'нато', 'комиссия', 'венгрия', 'язык'],
#  ['армия', 'румыния', 'нато', 'молдавия', 'республика'],
#  ['украина', 'россия', 'крым', 'рф', 'агрессия'],
#  ['композиция', 'телевизор', 'искусство', 'альбом', 'песня'],
#  ['год', 'поликлиника', 'врач', 'здравоохранение', 'пациент'],
#  ['соглашение', 'великобритания', 'страна', 'климат', 'финансирование'],
#  ['порошенко', 'симпатия', 'выбор', 'тимошенко', 'партия'],
#  ['книга', 'папа', 'человек', 'текст', 'детство'],
#  ['титов', 'встреча', 'путин', 'состав', 'вопрос'],
#  ['нато', 'украина', 'членство', 'порошенко', 'план'],
#  ['год', 'рождаемость', 'коэффициент', 'ребёнок', 'число'],
#  ['рынок', 'биржа', 'инфраструктура', 'экономика', 'площадка'],
#  ['клуб', 'год', 'игра', 'матч', 'традиция'],
#  ['театр', 'фестиваль', 'постановка', 'спектакль', 'проект'],
#  ['байкал', 'озеро', 'год', 'экология', 'русало'],
#  ['наука', 'бизнес', 'проект', 'знание', 'исследование'],
#  ['команда', 'гонка', 'шина', 'круг', 'подиум'],
#  ['кириллица', 'язык', 'письменность', 'народ', 'республика'],
#  ['корея', 'республика', 'страна', 'год', 'рост'],
#  ['осколок', 'тело', 'земля', 'год', 'падение'],
#  ['абхазия', 'вто', 'россия', 'тбилиси', 'грузия'],
#  ['россия', 'путин', 'победа', 'партия', 'прорыв'],
#  ['режиссёр', 'театр', 'создание', 'сцена', 'шукшин'],
#  ['молдавия', 'президент', 'автономия', 'совет', 'гагауз'],
#  ['книга', 'метр', 'др', 'революция', 'джаз'],
#  ['огонь', 'архимандрит', 'чудо', 'гроб', 'пасха'],
#  ['санкция', 'проект', 'нефть', 'шельф', 'сотрудничество'],
#  ['газа', 'газ', 'поток', 'газопровод', 'болгария'],
#  ['год', 'египет', 'египтянин', 'режим', 'фунт'],
#  ['архимандрит', 'еврей', 'раввин', 'миссия', 'литр'],
#  ['игра', 'волонтёр', 'медаль', 'область', 'год'],
#  ['язык', 'республика', 'совещание', 'шутка', 'часть'],
#  ['оркестр', 'симфония', 'татарстан', 'музыка', 'музыкант'],
#  ['система', 'пехота', 'вмс', 'сша', 'разведка'],
#  ['колледж', 'заявление', 'услуга', 'медик', 'медработник'],
#  ['команда', 'гонка', 'пилот', 'бразилия', 'трасса'],
#  ['год', 'тунис', 'революция', 'режим', 'власть'],
#  ['волкер', 'киев', 'миссия', 'сша', 'обсе'],
#  ['крым', 'вод', 'полуостров', 'миллиард', 'украина'],
#  ['дивизия', 'год', 'техника', 'армия', 'состав'],
#  ['энергетика', 'развитие', 'технология', 'дипломатия', 'сотрудничество'],
#  ['ес', 'год', 'британия', 'германия', 'проект'],
#  ['миркина', 'философ', 'вечер', 'мыслитель', 'год'],
#  ['республика', 'мечеть', 'ингушетия', 'акция', 'муфтий'],
#  ['великобритания', 'россия', 'газета', 'президент', 'дочь'],
#  ['гонка', 'грачев', 'заезд', 'пилот', 'итальянец'],
#  ['спектакль', 'театр', 'опера', 'тенор', 'сопрано'],
#  ['петипа', 'балет', 'танец', 'балерина', 'театр'],
#  ['стоимость', 'проект', 'прокладка', 'миллиард', 'газопровод'],
#  ['культура', 'литература', 'мыслитель', 'философия', 'зарубежье'],
#  ['пепеляев', 'юзеф', 'книга', 'якутия', 'восстание'],
#  ['отход', 'производство', 'русало', 'пыль', 'промышленность'],
#  ['касьянов', 'парнас', 'партия', 'съезд', 'праймериза'],
#  ['пилот', 'гонка', 'чемпионат', 'позиция', 'афанасьев'],
#  ['ракета', 'бомбардировщик', 'авиация', 'сирия', 'рф'],
#  ['жизнь', 'герцен', 'книга', 'человек', 'чиновник'],
#  ['год', 'прокуратура', 'дума', 'журналистка', 'статья'],
#  ['зарплата', 'опрос', 'статистика', 'респондент', 'гражданин'],
#  ['манёвр', 'бюджет', 'налог', 'правительство', 'рост'],
#  ['взнос', 'год', 'путин', 'страна', 'европа'],
#  ['трамп', 'путин', 'вторник', 'ссылка', 'кремль'],
#  ['электроэнергия', 'установка', 'принцип', 'изобретение', 'движение'],
#  ['донбасс', 'украина', 'миротворец', 'волкер', 'киев'],
#  ['интернет', 'власть', 'сеть', 'общество', 'информация'],
#  ['армения', 'президент', 'кандидат', 'депутат', 'партия'],
#  ['американец', 'культура', 'терроризм', 'человек', 'америка'],
#  ['назарбаев', 'азия', 'китай', 'мирзиёев', 'одкб'],
#  ['бог', 'стихотворение', 'поэт', 'человек', 'поэзия'],
#  ['самолёт', 'авиакатастрофа', 'крушение', 'песок', 'минобороны'],
#  ['троцкий', 'ленин', 'революция', 'нарком', 'год'],
#  ['витебск', 'комплекс', 'вертолёт', 'оборона', 'сирия'],
#  ['интернет', 'политика', 'газета', 'информация', 'сми'],
#  ['сотрудник', 'ингушетия', 'боевик', 'район', 'ранение'],
#  ['добыча', 'лукойл', 'нефтедобыча', 'год', 'показатель'],
#  ['сочи', 'билет', 'мероприятие', 'трасса', 'доставка'],
#  ['колчак', 'большевик', 'красных', 'правительство', 'правитель'],
#  ['арктика', 'нефть', 'добыча', 'месторождение', 'регион'],
#  ['фильм', 'кино', 'проект', 'миллион', 'продюсер'],
#  ['высоцкий', 'книга', 'дядя', 'метр', 'достоевский'],
#  ['воробьев', 'губернатор', 'благоустройство', 'программа', 'послание'],
#  ['табаков', 'рпц', 'священник', 'воля', 'спектакль'],
#  ['книга', 'метр', 'автор', 'поэзия', 'роман'],
#  ['продукция', 'год', 'предприятие', 'производство', 'вертолёт'],
#  ['компания', 'стенд', 'выставка', 'система', 'аппарат'],
#  ['ес', 'страна', 'саммит', 'конституция', 'вопрос'],
#  ['цик', 'год', 'лидер', 'состав', 'украина'],
#  ['герой', 'книга', 'автор', 'магдалинов', 'антиутопия'],
#  ['болгария', 'патриарх', 'передача', 'президент', 'партия'],
#  ['конкурс', 'театр', 'опера', 'песня', 'программа'],
#  ['иск', 'суд', 'арбитраж', 'год', 'инвестор'],
#  ['прокуратура', 'преступность', 'республика', 'год', 'борьба'],
#  ['слуцкий', 'журналистка', 'чемпионат', 'депутат', 'госдума'],
#  ['доход', 'год', 'население', 'зарплата', 'уровень'],
#  ['япония', 'россия', 'компания', 'сотрудничество', 'проект'],
#  ['сирия', 'россия', 'сила', 'возможность', 'операция'],
#  ['газопровод', 'сирия', 'катар', 'турция', 'газа'],
#  ['еаэс', 'соглашение', 'страна', 'услуга', 'цепочка'],
#  ['кино', 'зритель', 'театр', 'аудитория', 'ленсовет'],
#  ['апелляция', 'защита', 'теология', 'наука', 'минобрнаука'],
#  ['сирия', 'дамаск', 'формирование', 'вашингтон', 'армия'],
#  ['росатом', 'энергетика', 'россия', 'строительство', 'ветроэнергетика'],
#  ['греция', 'рынок', 'китай', 'доллар', 'инвестор'],
#  ['революция', 'философия', 'статья', 'учение', 'философ'],
#  ['экономика', 'лукашенко', 'декрет', 'белоруссия', 'технология'],
#  ['клетка', 'железо', 'процесс', 'испытание', 'премия'],
#  ['фонд', 'ветеран', 'память', 'помощь', 'поколение'],
#  ['бек', 'литература', 'встреча', 'год', 'книга'],
#  ['аэс', 'реактор', 'мощность', 'год', 'авария'],
#  ['большинство', 'ливан', 'оппозиция', 'президент', 'коалиция'],
#  ['ваххабит', 'мусульманин', 'азия', 'узбекистан', 'год'],
#  ['участник', 'эссеист', 'узник', 'невзгода', 'культуролог'],
#  ['саакашвили', 'украина', 'киев', 'суд', 'заседание'],
#  ['человек', 'молодая', 'церковь', 'общество', 'качество'],
#  ['чечня', 'комиссар', 'человек', 'рф', 'правозащитник'],
#  ['арктика', 'медведь', 'россия', 'флаг', 'слон'],
#  ['приднестровье', 'украина', 'молдавия', 'кишинев', 'молдова'],
#  ['книга', 'сборник', 'чтение', 'день', 'текст'],
#  ['уса', 'грудинин', 'выбор', 'николай', 'процент'],
#  ['алиев', 'журналист', 'пресса', 'азербайджан', 'баку'],
#  ['преступление', 'дело', 'специалист', 'условие', 'скрипаль'],
#  ['митинг', 'шествие', 'немцов', 'выступление', 'акция'],
#  ['фантастика', 'империя', 'монархия', 'историк', 'фантаст'],
#  ['швейцария', 'вто', 'россия', 'греф', 'инвестиция'],
#  ['россия', 'страна', 'конфликт', 'война', 'мир'],
#  ['критика', 'критик', 'литература', 'суждение', 'книга'],
#  ['эйзенштейн', 'фильм', 'мексика', 'режиссёр', 'оттенок'],
#  ['технология', 'русало', 'производство', 'экология', 'компания'],
#  ['сфера', 'путин', 'государство', 'палата', 'парламентарий'],
#  ['танк', 'защита', 'израиль', 'год', 'бронетехника'],
#  ['байкал', 'год', 'осадка', 'метр', 'осадок'],
#  ['школа', 'происшествие', 'ребёнок', 'пистолет', 'пострадавший'],
#  ['технология', 'русало', 'производство', 'экология', 'компания'],
#  ['сирия', 'авиация', 'самолёт', 'путин', 'ракета'],
#  ['конкурс', 'тысяча', 'список', 'участник', 'победитель'],
#  ['путин', 'программа', 'предложение', 'гражданин', 'особенность'],
#  ['нефть', 'арктика', 'шельф', 'добыча', 'сибирь'],
#  ['секунда', 'эфир', 'время', 'программа', 'год'],
#  ['рф', 'турбина', 'тэс', 'мвт', 'замминистра'],
#  ['коллега', 'губернатор', 'династия', 'надпись', 'бог'],
#  ['посол', 'рен', 'финляндия', 'язык', 'россия'],
#  ['строительство', 'заповедник', 'трасса', 'сочи', 'решение'],
#  ['муфтий', 'мусульманин', 'автор', 'деятель', 'богослов'],
#  ['парк', 'билет', 'посетитель', 'тысяча', 'матч'],
#  ['операция', 'конфликт', 'сторона', 'контингент', 'украина'],
#  ['литва', 'область', 'ес', 'проблема', 'калининград'],
#  ['жюри', 'фильм', 'приз', 'награда', 'медведь'],
#  ['друг', 'ряд', 'дюма', 'шапочка', 'кот'],
#  ['гудков', 'кандидат', 'мэр', 'явлинский', 'кампания'],
#  ['оружие', 'китай', 'экспорт', 'год', 'рынок'],
#  ['андерсон', 'нить', 'режиссёр', 'герой', 'работа'],
#  ['тенишев', 'книга', 'герр', 'романов', 'художник'],
#  ['фильм', 'женщина', 'выбор', 'мужчина', 'жена'],
#  ['папа', 'конгрегация', 'перевод', 'богослужение', 'епископ'],
#  ['поезд', 'вагон', 'револьвер', 'степь', 'старушка'],
#  ['театр', 'худрук', 'дело', 'директор', 'платформа'],
#  ['рождаемость', 'интернет', 'секс', 'россиянин', 'автомобиль'],
#  ['турция', 'политика', 'анкара', 'идеология', 'россия'],
#  ['скульптура', 'картина', 'портрет', 'коллекция', 'пикассо'],
#  ['год', 'египет', 'египтянин', 'режим', 'фунт'],
#  ['собчак', 'пожар', 'дом', 'ребёнок', 'чп'],
#  ['помпео', 'трамп', 'тиллерсон', 'госсекретарь', 'президент'],
#  ['путин', 'россия', 'власть', 'разделение', 'государство'],
#  ['воспоминание', 'дума', 'министерство', 'керенский', 'сообщение'],
#  ['закон', 'обращение', 'год', 'голодовка', 'животное'],
#  ['чехов', 'актриса', 'книга', 'князь', 'сказка'],
#  ['стих', 'тишина', 'шенкман', 'рассказ', 'буним'],
#  ['пласт', 'нефть', 'скважина', 'добыча', 'трещина'],
#  ['ребёнок', 'родитель', 'класс', 'образование', 'школа'],
#  ['соль', 'яд', 'минздрав', 'алкоголь', 'критерий'],
#  ['километр', 'поезд', 'час', 'китай', 'строительство'],
#  ['москва', 'власть', 'ответственность', 'грузия', 'россия'],
#  ['остров', 'япония', 'путин', 'год', 'россия'],
#  ['вод', 'вода', 'водооборот', 'очистка', 'завод'],
#  ['жизнь', 'враньё', 'кайф', 'человек', 'русь'],
#  ['дурак', 'жена', 'монумент', 'толерантность', 'муж'],
#  ['камень', 'башня', 'кусок', 'берег', 'городок'],
#  ['закон', 'агрессия', 'украина', 'оон', 'конфликт'],
#  ['свинья', 'вздох', 'бабушка', 'дело', 'дедушка'],
#  ['вто', 'азербайджан', 'документ', 'страна', 'баку'],
#  ['эстония', 'убыток', 'ущерб', 'латвия', 'миллиард'],
#  ['музей', 'выставка', 'портрет', 'картина', 'произведение'],
#  ['росатом', 'закупка', 'поставщик', 'корпорация', 'госкорпорация'],
#  ['законопроект', 'экзамен', 'крым', 'школа', 'форма'],
#  ['мо', 'управление', 'пентагон', 'закупка', 'военный'],
#  ['аравия', 'сша', 'трамп', 'сальман', 'визит'],
#  ['успех', 'достижение', 'власть', 'культура', 'государство'],
#  ['премия', 'ярмарка', 'поэт', 'поэзия', 'лауреат'],
#  ['человек', 'автомобиль', 'техносфера', 'год', 'актор'],
#  ['заболевание', 'воздух', 'лечение', 'препарат', 'пыль'],
#  ['фильм', 'герой', 'холл', 'рыцарь', 'конец'],
#  ['год', 'декабрь', 'электроэнергия', 'энергосистема', 'выработка'],
#  ['ракета', 'сармат', 'комплекс', 'система', 'испытание'],
#  ['академия', 'соловьев', 'студент', 'декан', 'ректор'],
#  ['операция', 'крым', 'сила', 'идея', 'спецназ'],
#  ['год', 'миллиард', 'информация', 'рубль', 'ук'],
#  ['гонка', 'пилот', 'трасса', 'машина', 'заезд'],
#  ['занятость', 'работник', 'труд', 'человек', 'группа'],
#  ['ирландия', 'день', 'символ', 'праздник', 'век'],
#  ['семинар', 'экскурсия', 'участник', 'антология', 'знакомство'],
#  ['газа', 'год', 'утилизация', 'газ', 'факел'],
#  ['сирия', 'дамаск', 'формирование', 'вашингтон', 'армия'],
#  ['взрыв', 'остров', 'индонезия', 'теракт', 'год'],
#  ['хокинг', 'ньютон', 'год', 'бас', 'лекция'],
#  ['реальность', 'знание', 'развитие', 'будущее', 'страна'],
#  ['берег', 'евфрат', 'сила', 'река', 'форсирование'],
#  ['косово', 'церковь', 'албания', 'католик', 'серб'],
#  ['сон', 'фаза', 'человек', 'время', 'цикл'],
#  ['музей', 'год', 'искусство', 'церемония', 'выставка'],
#  ['бригада', 'скора', 'вызов', 'помощь', 'станция'],
#  ['беспилотник', 'компания', 'аппарат', 'система', 'год'],
#  ['книга', 'чуковский', 'год', 'пётр', 'теория'],
#  ['бундестаг', 'сдпг', 'коалиция', 'партия', 'правительство'],
#  ['приднестровье', 'кишинев', 'ес', 'тирасполь', 'рф'],
#  ['вагон', 'дорога', 'рельс', 'писатель', 'паровоз'],
#  ['пхеньян', 'кндр', 'диалог', 'корея', 'переговоры'],
#  ['сталин', 'народ', 'кавказ', 'немец', 'год'],
#  ['мост', 'уголь', 'хакасия', 'строительство', 'месторождение'],
#  ['греция', 'референдум', 'евро', 'ципраса', 'кризис'],
#  ['судья', 'стража', 'дело', 'жалоба', 'суд'],
#  ['фильм', 'священник', 'клуб', 'франко', 'драма'],
#  ['чен', 'кндр', 'год', 'руководитель', 'праздник'],
#  ['таджикистан', 'свобода', 'организация', 'душанбе', 'ячейка'],
#  ['реформатор', 'теория', 'год', 'доход', 'экономика'],
#  ['новичок', 'рф', 'солсбери', 'мид', 'великобритания'],
#  ['вода', 'плотность', 'вод', 'год', 'луч'],
#  ['тенишев', 'книга', 'герр', 'романов', 'художник'],
#  ['мид', 'шеф', 'англичанин', 'посольство', 'кгб'],
#  ['греция', 'кредитор', 'правительство', 'саммит', 'дефолт'],
#  ['артамонов', 'горький', 'дело', 'фабрика', 'человек'],
#  ['год', 'уголь', 'добыча', 'нефть', 'страна'],
#  ['аргентина', 'фонд', 'храм', 'священнослужитель', 'деятельность'],
#  ['фильм', 'теракт', 'героиня', 'бекмамбетов', 'картина'],
#  ['доход', 'выплата', 'январь', 'год', 'росстат'],
#  ['арктика', 'музей', 'ледокол', 'петербург', 'металлолом'],
#  ['афганистан', 'азия', 'иго', 'боевик', 'сирия'],
#  ['туркменистан', 'выбор', 'сын', 'преемник', 'президент'],
#  ['конференция', 'встреча', 'четвёрка', 'четверг', 'дипломат'],
#  ['савченко', 'рада', 'депутат', 'генпрокуратура', 'теракт'],
#  ['удар', 'израиль', 'сирия', 'пво', 'сша'],
#  ['самолёт', 'истребитель', 'сирия', 'система', 'цель'],
#  ['горький', 'максим', 'писатель', 'никитин', 'жизнь'],
#  ['фильм', 'режиссёр', 'женщина', 'комедия', 'приз'],
#  ['слуцкий', 'журналистка', 'чемпионат', 'депутат', 'госдума'],
#  ['ревность', 'любовь', 'измена', 'секс', 'женщина'],
#  ['друг', 'минута', 'пощёчина', 'праздник', 'мужчина'],
#  ['будда', 'сенкевич', 'религия', 'жизнь', 'автор'],
#  ['интернет', 'политика', 'кампания', 'путин', 'человек'],
#  ['германия', 'шульц', 'газета', 'сдпг', 'издание'],
#  ['компания', 'маска', 'космонавтика', 'маск', 'заказ'],
#  ['обсерватория', 'наблюдение', 'зона', 'застройщик', 'суд'],
#  ['старообрядец', 'церковь', 'эстония', 'сотрудничество', 'традиция'],
#  ['экономика', 'россия', 'топливо', 'соглашение', 'ископаемое'],
#  ['терроризм', 'оон', 'государство', 'совет', 'безопасность'],
#  ['экипаж', 'самолёт', 'лайнер', 'высота', 'скорость'],
#  ['газопровод', 'газпром', 'газа', 'год', 'куб'],
#  ['пацан', 'депутат', 'время', 'дума', 'ночь'],
#  ['чаша', 'факел', 'оао', 'кузнецов', 'игра'],
#  ['евро', 'ципраса', 'брюссель', 'миллиард', 'грек'],
#  ['алюминий', 'русало', 'производство', 'металл', 'отход'],
#  ['ирландия', 'день', 'символ', 'праздник', 'век'],
#  ['ес', 'вопрос', 'дело', 'германия', 'реформа'],
#  ['спортсмен', 'тренер', 'уха', 'символика', 'эмират'],
#  ['сирия', 'самолёт', 'военный', 'россия', 'турция'],
#  ['доллар', 'наряд', 'коллекция', 'торг', 'предмет'],
#  ['концерт', 'горбунов', 'выбор', 'артист', 'билет'],
#  ['долг', 'рубль', 'должник', 'услуга', 'жкх'],
#  ['игра', 'олимпиада', 'сочи', 'закрытие', 'церемония'],
#  ['клетка', 'кожа', 'частица', 'ген', 'слой'],
#  ['редактор', 'писатель', 'наука', 'литература', 'слово'],
#  ['россия', 'страна', 'показатель', 'среда', 'природа'],
#  ['пакистан', 'рф', 'россия', 'эгида', 'лавров'],
#  ['оон', 'грузия', 'абхазия', 'тбилиси', 'конфликт'],
#  ['академик', 'наука', 'статья', 'комиссия', 'дисциплина'],
#  ['дед', 'жидкость', 'бутыль', 'аппарат', 'дерево'],
#  ['год', 'молодёжь', 'активность', 'лифт', 'движение'],
#  ['партия', 'яблоко', 'год', 'женщина', 'человек'],
#  ['крокодил', 'речушка', 'берег', 'бассейн', 'вода'],
#  ['отель', 'турист', 'россиянин', 'россия', 'колледж'],
#  ['гонка', 'пилот', 'трасса', 'феттель', 'мексика'],
#  ['поезд', 'дорога', 'система', 'год', 'россия'],
#  ['мост', 'уголь', 'хакасия', 'строительство', 'месторождение'],
#  ['потребитель', 'аэс', 'мощность', 'год', 'цена'],
#  ['экипаж', 'полёт', 'самолёт', 'высота', 'сирия'],
#  ['пункт', 'минздрав', 'помощь', 'год', 'тысяча'],
#  ['победительница', 'красота', 'войско', 'конкурс', 'военный'],
#  ['россия', 'солсбери', 'отравление', 'дочь', 'возможность'],
#  ['папа', 'церковь', 'кардинал', 'сериал', 'бог'],
#  ['артамонов', 'горький', 'дело', 'фабрика', 'человек'],
#  ['зарплата', 'тысяча', 'год', 'рубль', 'данные'],
#  ['композиция', 'самолёт', 'авиакатастрофа', 'мемориал', 'рф'],
#  ['остров', 'япония', 'деятельность', 'курил', 'токио'],
#  ['гудков', 'кандидат', 'мэр', 'явлинский', 'кампания'],
#  ['лишение', 'паспорт', 'проверка', 'крым', 'человек'],
#  ['компания', 'выставка', 'ветроэнергетика', 'рынок', 'мощность'],
#  ['друг', 'минута', 'пощёчина', 'праздник', 'мужчина'],
#  ['девочка', 'мама', 'нога', 'школа', 'бабушка'],
#  ['книжка', 'похороны', 'глава', 'кирпичик', 'телефильм'],
#  ['тайвань', 'китай', 'си', 'авианосец', 'цзиньпин'],
#  ['киберпространство', 'подразделение', 'войско', 'сша', 'противник'],
#  ['механик', 'командир', 'машинка', 'корабль', 'дивизия'],
#  ['гражданство', 'паспорт', 'крым', 'беженец', 'рф'],
#  ['металл', 'производство', 'продукция', 'завод', 'изделие'],
#  ['сухогруз', 'экипаж', 'шторм', 'мчс', 'танкер'],
#  ['одномандатник', 'кпрф', 'горсовет', 'новосибирск', 'депутат'],
#  ['патриарх', 'болгария', 'март', 'епископ', 'церковь'],
#  ['остров', 'япония', 'путин', 'год', 'россия'],
#  ['возраст', 'утрата', 'экономика', 'цифровизация', 'человек'],
#  ['киргизия', 'страна', 'год', 'посол', 'джихад'],
#  ['проект', 'выброс', 'сбербанк', 'тонна', 'конкурс'],
#  ['община', 'власть', 'документ', 'молодёжь', 'еврей'],
#  ['дорога', 'скорость', 'автомобилист', 'стоянка', 'мвд'],
#  ['россия', 'партия', 'страна', 'депутат', 'год'],
#  ['врач', 'грант', 'статус', 'пациент', 'рубль'],
#  ['ходорковский', 'путин', 'россия', 'оппозиция', 'юкос'],
#  ['поэт', 'клуб', 'писатель', 'выставка', 'вечер'],
#  ['поэт', 'малыш', 'луч', 'цвет', 'жизнь'],
#  ['сирия', 'гута', 'рф', 'дамаск', 'оон'],
#  ['послание', 'год', 'путин', 'зарплата', 'экономика'],
#  ['год', 'экономика', 'россия', 'рынок', 'тэк'],
#  ['греция', 'еврогруппа', 'предложение', 'еврозона', 'страна'],
#  ['язва', 'потепление', 'побережье', 'вскрытие', 'страна'],
#  ['поэт', 'клуб', 'писатель', 'выставка', 'вечер'],
#  ['гута', 'оружие', 'сила', 'район', 'герасимов'],
#  ['водохранилище', 'вода', 'переброска', 'год', 'бассейн'],
#  ['преступление', 'дело', 'специалист', 'условие', 'скрипаль'],
#  ['технополис', 'воронеж', 'рота', 'исследование', 'оборона'],
#  ['скора', 'бригада', 'станция', 'помощь', 'минута'],
#  ['команда', 'пилот', 'трасса', 'болид', 'автодром'],
#  ['поезд', 'дорога', 'система', 'год', 'россия'],
#  ['повесть', 'страна', 'книга', 'рыбка', 'одиночество'],
#  ['экология', 'компания', 'русало', 'экомарафон', 'волна'],
#  ['сша', 'сирия', 'армия', 'курд', 'турция'],
#  ['слово', 'автор', 'стих', 'друг', 'ангел'],
#  ['команда', 'сериал', 'актёр', 'презентация', 'космонавт'],
#  ['организация', 'наблюдатель', 'статус', 'конфликт', 'год'],
#  ['каток', 'лёд', 'вднх', 'парка', 'сокольник'],
#  ['энергия', 'самолёт', 'здание', 'энергетика', 'метр'],
#  ['сотрудничество', 'программа', 'гройсман', 'министр', 'кабинет'],
#  ['гэс', 'монголия', 'байкал', 'проект', 'селенга'],
#  ['обращение', 'количество', 'прокуратура', 'жалоба', 'орган'],
#  ['рейтинг', 'работодатель', 'росатом', 'компания', 'госкорпорация'],
#  ['микроскоп', 'год', 'молекула', 'метод', 'премия'],
#  ['система', 'робот', 'интеллект', 'человек', 'страна'],
#  ['приднестровье', 'ес', 'страна', 'продукция', 'молдавия'],
#  ['университет', 'рейтинг', 'вуз', 'предмет', 'ректор'],
#  ['команда', 'гонка', 'сезон', 'компания', 'чемпионат'],
#  ['команда', 'сезон', 'пилот', 'сторона', 'медь'],
#  ['эволюция', 'человек', 'грызун', 'доклад', 'музей'],
#  ['казань', 'аэропорт', 'самолёт', 'татарстан', 'посадка'],
#  ['украина', 'явлинский', 'вопрос', 'президент', 'тема'],
#  ['корбина', 'дело', 'путин', 'лейборист', 'выдержка'],
#  ['резолюция', 'оон', 'расследование', 'сирия', 'требование'],
#  ['манёвр', 'бюджет', 'налог', 'правительство', 'рост'],
#  ['табаков', 'рпц', 'священник', 'воля', 'спектакль'],
#  ['протест', 'акция', 'оппозиция', 'май', 'инаугурация'],
#  ['гута', 'удар', 'сша', 'сирия', 'дамаск'],
#  ['поставка', 'экспорт', 'нефть', 'год', 'газа'],
#  ['гонка', 'машина', 'нико', 'болид', 'обгон'],
#  ['квалификация', 'время', 'сегмент', 'пилот', 'первое'],
#  ['цена', 'молдавия', 'газпром', 'газ', 'пересмотр'],
#  ['год', 'группировка', 'брат', 'египет', 'мурси'],
#  ['поэт', 'поэзия', 'стих', 'стихосложение', 'рифма'],
#  ['газпром', 'транзит', 'газа', 'украина', 'миллиард'],
#  ['год', 'египет', 'египтянин', 'режим', 'фунт'],
#  ['список', 'санкция', 'грузия', 'документ', 'гражданин'],
#  ['дебаты', 'собчак', 'грудинин', 'жириновский', 'электорат'],
#  ['фильм', 'песня', 'лёд', 'петров', 'тарасов'],
#  ['байкал', 'фильм', 'мусор', 'экология', 'территория'],
#  ['пилот', 'квалификация', 'болид', 'трасса', 'хунгароринг'],
#  ['человек', 'молодая', 'церковь', 'общество', 'качество'],
#  ['книга', 'мемуарист', 'литератор', 'поэт', 'мемуары'],
#  ['россия', 'санкция', 'сша', 'оружие', 'лавров'],
#  ['законопроект', 'украина', 'киев', 'страна', 'суд'],
#  ['фильм', 'зайцев', 'режиссёр', 'мальчик', 'герой'],
#  ['новичок', 'рф', 'солсбери', 'мид', 'великобритания'],
#  ['оружие', 'китай', 'экспорт', 'год', 'рынок'],
#  ['стих', 'проза', 'текст', 'интервью', 'бутусов'],
#  ['квалификация', 'пилот', 'штраф', 'ситроен', 'заезд'],
#  ['троцкий', 'ленин', 'революция', 'нарком', 'год'],
#  ['глушков', 'смерть', 'адвокат', 'аэрофлот', 'хищение'],
#  ['система', 'лужники', 'посетитель', 'зона', 'болельщик'],
#  ['корабль', 'история', 'византия', 'колесо', 'князь'],
#  ['аэропорт', 'посёлок', 'бишкек', 'полоса', 'самолёт'],
#  ['грузия', 'вредитель', 'фермер', 'крестьянин', 'год'],
#  ['нико', 'болид', 'сегмент', 'двигатель', 'команда'],
#  ['доллар', 'наряд', 'коллекция', 'торг', 'предмет'],
#  ['название', 'оружие', 'ракета', 'вид', 'президент'],
#  ['выброс', 'газ', 'развитие', 'цель', 'соглашение'],
#  ['грузия', 'абхазия', 'осетия', 'россия', 'отношение'],
#  ['буш', 'страна', 'угроза', 'ирак', 'ладен'],
#  ['чечня', 'кадыров', 'обращение', 'правозащитник', 'мвд'],
#  ['гранат', 'тайник', 'селение', 'мина', 'выстрел'],
#  ['культура', 'книга', 'анализ', 'хемингуэй', 'документ'],
#  ['книга', 'нея', 'любовь', 'шкаф', 'оригинал'],
#  ['операция', 'крым', 'сила', 'идея', 'спецназ'],
#  ['поликлиника', 'врач', 'пациент', 'приём', 'сервис'],
#  ['дельфин', 'остров', 'человек', 'михеев', 'ребёнок'],
#  ['серов', 'мощность', 'отключение', 'электростанция', 'полуостров'],
#  ['гэс', 'монголия', 'река', 'байкал', 'проект'],
#  ['доклад', 'гражданство', 'мигрант', 'право', 'правозащитник'],
#  ['пошлина', 'товар', 'сша', 'импорт', 'китай'],
#  ['украина', 'порошенко', 'меджлис', 'татарин', 'мусульманин'],
#  ['ливия', 'кампания', 'евро', 'дело', 'париж'],
#  ['сердце', 'спортсмен', 'остановка', 'обследование', 'год'],
#  ['программа',
#   'соотечественник',
#   'переселенец',
#   'госпрограмма',
#   'переселение'],
#  ['поезд', 'дорога', 'система', 'год', 'россия'],
#  ['фракция', 'группировка', 'джейша', 'сирия', 'оппозиция'],
#  ['роба', 'гонка', 'чилтон', 'ситроен', 'автомобиль'],
#  ['экономика', 'технология', 'закон', 'чиновник', 'толкование'],
#  ['спектакль', 'театр', 'петренко', 'зал', 'гитис'],
#  ['компания', 'стенд', 'выставка', 'система', 'аппарат'],
#  ['индустрия', 'технология', 'производство', 'фабрика', 'экономика'],
#  ['кинжал', 'комплекс', 'ракета', 'минобороны', 'дежурство'],
#  ['бёрдо', 'леди', 'гервиг', 'фильм', 'режиссёр'],
#  ['клуб', 'член', 'бизнес', 'человек', 'бизнесмен'],
#  ['войско', 'американец', 'корея', 'оон', 'дивизия'],
#  ['театр', 'табаков', 'режиссёр', 'спектакль', 'преемник'],
#  ['конкурс', 'тысяча', 'список', 'участник', 'победитель'],
#  ['помпео', 'мусульманин', 'назначение', 'должность', 'сша'],
#  ['путин', 'кандидат', 'собчак', 'неделя', 'теледебаты'],
#  ['геном', 'неандерталец', 'ген', 'человек', 'житель'],
#  ['помилование', 'прошение', 'ходатайство', 'юкос', 'адвокат'],
#  ['надпись', 'лёд', 'фонтанка', 'агитация', 'избирком'],
#  ['бизнес', 'ребёнок', 'проект', 'предприниматель', 'предпринимательство'],
#  ['разведчик', 'книга', 'герой', 'спецслужба', 'работа'],
#  ['сон', 'фаза', 'человек', 'время', 'цикл'],
#  ['диалектика', 'революция', 'марксизм', 'социализм', 'теория'],
#  ['питание', 'сочи', 'тысяча', 'продукт', 'день'],
#  ['американка', 'победа', 'сочи', 'бронза', 'шайба'],
#  ['миллион', 'год', 'человек', 'вид', 'вымирание'],
#  ['аппарат', 'система', 'полёт', 'беспилотник', 'килограмм'],
#  ['фильм', 'герой', 'роль', 'спектакль', 'театр'],
#  ['дом', 'день', 'нея', 'окно', 'жизнь'],
#  ['госдума', 'партия', 'создание', 'олимп', 'емельянов'],
#  ['нато', 'королевство', 'россия', 'британия', 'отравление'],
#  ['список', 'организация', 'хезболл', 'группировка', 'аравия'],
#  ['чемпионат', 'автомобиль', 'команда', 'производитель', 'участие'],
#  ['турция', 'вашингтон', 'анкара', 'отношение', 'кипение'],
#  ['система', 'аппарат', 'беспилотник', 'сша', 'год'],
#  ['македония', 'греция', 'ес', 'год', 'церковь'],
#  ['афганистан', 'группировка', 'кабул', 'страна', 'атака'],
#  ['отец', 'княжество', 'престол', 'башня', 'сын'],
#  ['километр', 'трасса', 'река', 'дорога', 'автотрасса'],
#  ['агентство', 'город', 'террорист', 'турция', 'пункт'],
#  ['строительство', 'сочи', 'объект', 'график', 'проектирование'],
#  ['язык', 'место', 'парламент', 'год', 'квота'],
#  ['путин', 'повестка', 'меньшинство', 'выбор', 'тема'],
#  ['допинг', 'соревнование', 'спорт', 'спортсмен', 'тренер'],
#  ['юкос', 'дело', 'хищение', 'расследование', 'актив'],
#  ['вднх', 'павильон', 'выставка', 'парк', 'модернизация'],
#  ['регулирование', 'выброс', 'квота', 'налог', 'страна'],
#  ['депозит', 'банка', 'средство', 'козак', 'госкорпорация'],
#  ['надпись', 'лёд', 'фонтанка', 'агитация', 'избирком'],
#  ['аэропорт', 'самолёт', 'авиакомпания', 'рейс', 'крушение'],
#  ['кровля', 'столица', 'снег', 'территория', 'осадок'],
#  ['сирия', 'группировка', 'иерусалим', 'дамаск', 'страна'],
#  ['коррупция', 'образование', 'противодействие', 'программа', 'участник'],
#  ['нии', 'год', 'препарат', 'производство', 'завод'],
#  ['ребёнок', 'площадка', 'лужники', 'взрослый', 'сад'],
#  ['метр', 'герр', 'эссе', 'воспоминание', 'книга'],
#  ['оркестр', 'фестиваль', 'хор', 'бах', 'трилогия'],
#  ['человек', 'год', 'рост', 'сантиметр', 'эволюция'],
#  ['высоцкий', 'рассказ', 'канал', 'смерть', 'проза'],
#  ['цру', 'пытка', 'тюрьма', 'сша', 'коллега'],
#  ['яблоко', 'отделение', 'партия', 'владивосток', 'конференция'],
#  ['мобилизация', 'руководитель', 'рекомендация', 'коллектив', 'явка'],
#  ['сталин', 'народ', 'кавказ', 'немец', 'год'],
#  ['путин', 'президент', 'интервью', 'эксперт', 'высказывание'],
#  ['рейтинг', 'росатом', 'индекс', 'работодатель', 'госкорпорация'],
#  ['росатом', 'аэс', 'энергоблок', 'год', 'реактор'],
#  ['конкурс', 'опыт', 'грант', 'обучение', 'победитель'],
#  ['фонд', 'рынок', 'инвестор', 'цена', 'стратегия'],
#  ['прокурор', 'закон', 'личность', 'сми', 'журналист'],
#  ['мечеть', 'поджог', 'германия', 'турция', 'наступление'],
#  ['стих', 'маяковский', 'книга', 'третьяков', 'стихотворение'],
#  ['донбасс', 'украина', 'закон', 'волкер', 'поставка'],
#  ['узбекистан', 'киргизия', 'мирзиёев', 'ташкент', 'вопрос'],
#  ['регион', 'зарплата', 'доход', 'рост', 'год'],
#  ['книга', 'поляков', 'стихотворение', 'стих', 'давыдов'],
#  ['котельная', 'зона', 'байкал', 'озеро', 'район'],
#  ['греция', 'пожар', 'район', 'огонь', 'пострадавший'],
#  ['крушение', 'самолёт', 'обломок', 'хлопок', 'авиалиния'],
#  ['пепеляев', 'юзеф', 'книга', 'якутия', 'восстание'],
#  ['автоспорт', 'расписание', 'весна', 'париж', 'осень'],
#  ['показ', 'спектакль', 'маска', 'кинотеатр', 'москва'],
#  ['наводнение', 'вода', 'ливень', 'рейн', 'дождь'],
#  ['удар', 'бомбардировщик', 'военный', 'авиация', 'пункт'],
#  ['россия', 'путин', 'победа', 'партия', 'прорыв'],
#  ['кандидат', 'выбор', 'церковь', 'выборы', 'агитация'],
#  ['гостиница', 'отель', 'компания', 'врио', 'год'],
#  ['ячейка', 'панель', 'электричество', 'энергия', 'кремний'],
#  ['финал', 'конкурс', 'здравоохранение', 'назначенец', 'министр'],
#  ['байкал', 'вклад', 'отрасль', 'туризм', 'китаец'],
#  ['сирия', 'сша', 'территория', 'режим', 'поддержка'],
#  ['партия', 'год', 'организация', 'россия', 'деятельность'],
#  ['миллион', 'год', 'животное', 'вид', 'вымирание'],
#  ['театр', 'фестиваль', 'режиссёр', 'спектакль', 'псков'],
#  ['трасса', 'пилот', 'болид', 'заезд', 'сессия'],
#  ['квалификация', 'пилот', 'авария', 'команда', 'сайнс'],
#  ['пилот', 'туринг', 'заезд', 'тарквини', 'мюллер'],
#  ['меркель', 'ес', 'канцлер', 'берлин', 'министр'],
#  ['алюминий', 'потребление', 'год', 'ассоциация', 'рынок'],
#  ['номинация', 'церемония', 'премия', 'актриса', 'сцена'],
#  ['река', 'гора', 'название', 'луга', 'хутор'],
#  ['здравоохранение', 'услуга', 'помощь', 'доклад', 'система'],
#  ['горожанин', 'город', 'парка', 'парк', 'мегаполис'],
#  ['знание', 'образование', 'технология', 'компетенция', 'школа'],
#  ['команда', 'гонка', 'трасса', 'заезд', 'феттель'],
#  ['ночлежка', 'квартира', 'ребёнок', 'вопрос', 'клиент'],
#  ['алюминий', 'производство', 'выброс', 'технология', 'экология'],
#  ['мо', 'управление', 'пентагон', 'закупка', 'военный'],
#  ['гонка', 'трасса', 'пилот', 'бокс', 'томпсон'],
#  ['жуков', 'вто', 'экономика', 'страна', 'вступление'],
#  ['огонь', 'архимандрит', 'чудо', 'гроб', 'пасха'],
#  ['вто', 'россия', 'швеция', 'пошлина', 'вопрос'],
#  ['сердце', 'спортсмен', 'остановка', 'обследование', 'год'],
#  ['ввс', 'космос', 'сша', 'пространство', 'военный'],
#  ['газа', 'миллиард', 'метр', 'газопровод', 'куб'],
#  ['конструктор', 'испытание', 'решение', 'создание', 'задача'],
#  ['газпром', 'тимошенко', 'украина', 'газа', 'нафтогаза'],
#  ['монархия', 'михалков', 'идея', 'человек', 'процент'],
#  ['женщина', 'мор', 'сестра', 'мужчина', 'право'],
#  ['пыль', 'уголь', 'терминал', 'воздух', 'находка'],
#  ['прокуратура', 'заявление', 'выигрыш', 'конверт', 'отдел'],
#  ['буш', 'сентябрь', 'безопасность', 'советник', 'администрация'],
#  ['теракт', 'комитет', 'поправка', 'сми', 'комиссаров'],
#  ['бич', 'карикатура', 'журнал', 'год', 'сатира'],
#  ['интернет', 'телевизор', 'политика', 'тв', 'канал'],
#  ['россия', 'партия', 'страна', 'депутат', 'год'],
#  ['акт', 'одиночка', 'организация', 'цель', 'лицо'],
#  ['украина', 'территория', 'донбасс', 'киев', 'рада'],
#  ['сюжет', 'серия', 'повествование', 'смысл', 'клякса'],
#  ['фильм', 'история', 'режиссёр', 'экран', 'смерть'],
#  ['газа', 'приднестровье', 'молдавия', 'кишинев', 'поставка'],
#  ['памятник', 'горький', 'вокзал', 'площадь', 'писатель'],
#  ['партия', 'италия', 'ес', 'движение', 'выбор'],
#  ['гонка', 'пилот', 'грачев', 'стефано', 'флаг'],
#  ['музей', 'выставка', 'охота', 'пушкин', 'октябрь'],
#  ['военный', 'взаимодействие', 'организация', 'наблюдатель', 'индия'],
#  ['музей', 'коллекция', 'искусство', 'собрание', 'выставка'],
#  ['вьетнам', 'воробей', 'молоко', 'концерн', 'проект'],
#  ['оплата', 'карта', 'пассажир', 'проезд', 'автобус'],
#  ['фильм', 'приз', 'картина', 'кино', 'медведь'],
#  ['фракция', 'группировка', 'джейша', 'сирия', 'оппозиция'],
#  ['экономика', 'россия', 'развитие', 'реализация', 'рост'],
#  ['журнал', 'обложка', 'коллекция', 'выставка', 'панорама'],
#  ['бьянки', 'авария', 'команда', 'заявление', 'француз'],
#  ['бетховен', 'фестиваль', 'варшава', 'музыка', 'симфония'],
#  ['тайфун', 'шторм', 'побережье', 'китай', 'синоптик'],
#  ['мгимо', 'фонд', 'университет', 'выпускник', 'год'],
#  ['рост', 'шувалов', 'правительство', 'манёвр', 'экономика'],
#  ['тайвань', 'китай', 'си', 'авианосец', 'цзиньпин'],
#  ['пропуск', 'машина', 'охранник', 'этаж', 'дед'],
#  ['явка', 'избиратель', 'кандидат', 'выбор', 'кампания'],
#  ['любовь', 'стихотворение', 'белые', 'герой', 'мир'],
#  ['модернизация', 'потребитель', 'оборудование', 'мощность', 'россия'],
#  ['реактор', 'аэс', 'энергетика', 'год', 'страна'],
#  ['фильм', 'драма', 'целое', 'история', 'актёр'],
#  ['оценщик', 'конкурс', 'компания', 'оценка', 'слово'],
#  ['папа', 'кардинал', 'епископ', 'ватикан', 'год'],
#  ['поэт', 'стихотворение', 'поэзия', 'сборник', 'стих'],
#  ['сша', 'спецслужба', 'шпионаж', 'год', 'шпион'],
#  ['вид', 'миллион', 'биосфера', 'биоразнообразие', 'животное'],
#  ['наука', 'рана', 'академия', 'сергеев', 'президент'],
#  ['зарплата', 'тысяча', 'год', 'рубль', 'данные'],
#  ['опека', 'комитет', 'пакт', 'нефтедобыча', 'приверженность'],
#  ['человек', 'автомобиль', 'техносфера', 'год', 'актор'],
#  ['крокодил', 'подполковник', 'товарищ', 'телезритель', 'шуба'],
#  ['фильм', 'кино', 'проект', 'миллион', 'продюсер'],
#  ['байкал', 'гэс', 'вода', 'озеро', 'уровень'],
#  ['рубль', 'издание', 'тысяча', 'год', 'торг'],
#  ['премьер', 'сочи', 'путин', 'проект', 'частность'],
#  ['поэт', 'поэзия', 'стих', 'стихосложение', 'рифма'],
#  ['еврозона', 'греция', 'евро', 'кредитор', 'референдум'],
#  ['страна', 'россия', 'кислород', 'пространство', 'территория'],
#  ['пилот', 'гонка', 'команда', 'гонщик', 'подиум'],
#  ['аудитория', 'команда', 'мир', 'бренд', 'человек'],
#  ['поэт', 'стих', 'слово', 'поэзия', 'тираж'],
#  ['экономика', 'лукашенко', 'декрет', 'белоруссия', 'технология'],
#  ['ливан', 'наука', 'должность', 'образование', 'россия'],
#  ['пациент', 'карта', 'здравоохранение', 'внедрение', 'москва'],
#  ['группа', 'афганистан', 'талибан', 'кветта', 'командир'],
#  ['отставка', 'лидер', 'президент', 'правление', 'здоровье'],
#  ['центр', 'пациент', 'инфаркт', 'помощь', 'москва'],
#  ['стандарт', 'васильев', 'источник', 'предмет', 'произведение'],
#  ['отход', 'год', 'земля', 'техносфера', 'биомасса'],
#  ['друг', 'минута', 'пощёчина', 'праздник', 'мужчина'],
#  ['партия', 'человек', 'россия', 'тысяча', 'уровень'],
#  ['посол', 'сеул', 'россия', 'размещение', 'президент'],
#  ['муссолини', 'партизан', 'милан', 'сало', 'немец'],
#  ['обращение', 'количество', 'прокуратура', 'жалоба', 'орган'],
#  ['монета', 'кошка', 'имя', 'клиент', 'дерево'],
#  ['эко', 'многоточие', 'рыцарь', 'жизнь', 'литр'],
#  ['учение', 'каспий', 'сша', 'регион', 'россия'],
#  ['книга', 'женщина', 'фрейд', 'мужчина', 'человек'],
#  ['зала', 'честь', 'военный', 'военачальник', 'корпус'],
#  ['мгимо', 'фонд', 'университет', 'выпускник', 'год'],
#  ['донбасс', 'украина', 'миротворец', 'волкер', 'киев'],
#  ['грудинин', 'подмосковье', 'кпрф', 'губернатор', 'кандидат'],
#  ['доклад', 'арктика', 'климат', 'сша', 'таяние'],
#  ['премия', 'номинация', 'философ', 'бердяев', 'комитет'],
#  ['год', 'премия', 'поэт', 'чтение', 'книга'],
#  ['метр', 'стих', 'польша', 'поэзия', 'лауреат'],
#  ['судан', 'военный', 'область', 'мероприятие', 'подготовка'],
#  ['поэт', 'северянин', 'предисловие', 'книга', 'автор'],
#  ['татунашвили', 'грузия', 'осетия', 'переговоры', 'тбилиси'],
#  ['жизнь', 'герцен', 'книга', 'человек', 'чиновник'],
#  ['котельная', 'зона', 'байкал', 'озеро', 'район'],
#  ['аспирантура', 'нии', 'аспирант', 'подготовка', 'аккредитация'],
#  ['эйзенштейн', 'книга', 'архив', 'музей', 'режиссёр'],
#  ['иностранец', 'икра', 'пример', 'ракета', 'комиссия'],
#  ['коваль', 'писатель', 'книга', 'клуб', 'человек'],
#  ['узбекистан', 'парламент', 'соглашение', 'гражданин', 'мирзиёев'],
#  ['пост', 'рейтинг', 'сеть', 'подписчик', 'миронов'],
#  ['язва', 'потепление', 'побережье', 'вскрытие', 'страна'],
#  ['объект', 'расход', 'сочи', 'год', 'олимпиада'],
#  ['метр', 'поэт', 'библиотека', 'март', 'центр'],
#  ['красота', 'отчаяние', 'глаз', 'порыв', 'кошка'],
#  ['экология', 'компания', 'русало', 'экомарафон', 'волна'],
#  ['человечек', 'аллюзия', 'капитал', 'детство', 'мир'],
#  ['книга', 'поляков', 'стихотворение', 'стих', 'давыдов'],
#  ['стих', 'маяковский', 'книга', 'третьяков', 'стихотворение'],
#  ['литвиненко', 'отравление', 'британия', 'шпион', 'покушение'],
#  ['фильм', 'конкурс', 'год', 'режиссёр', 'фестиваль'],
#  ['ирак', 'американец', 'война', 'сша', 'потеря'],
#  ['грузия', 'квирикашвили', 'мид', 'рф', 'татунашвили'],
#  ['повесть', 'год', 'писатель', 'мальчик', 'автор'],
#  ['гостиница', 'отель', 'компания', 'врио', 'год'],
#  ['дружина', 'полиция', 'орган', 'партия', 'корпус'],
#  ['стих', 'тишина', 'шенкман', 'рассказ', 'буним'],
#  ['харпер', 'буш', 'канада', 'саммит', 'встреча'],
#  ['иран', 'тиллерсон', 'трамп', 'сделка', 'сша'],
#  ['грудинин', 'цик', 'неделя', 'памфилов', 'кандидат'],
#  ['корабль', 'вмс', 'машина', 'год', 'ключ'],
#  ['герой', 'постмодернизм', 'мир', 'текст', 'человек'],
#  ['узник', 'еврей', 'священник', 'лагерь', 'смерть'],
#  ['петипа', 'балет', 'танец', 'балерина', 'театр'],
#  ['польша', 'украина', 'киев', 'решение', 'закон'],
#  ['бумага', 'выпуск', 'миллиард', 'доллар', 'минфин'],
#  ['договор', 'ратификация', 'киргизия', 'осуществление', 'поставка'],
#  ['поэт', 'одиночество', 'вагон', 'горький', 'журналист'],
#  ['дорога', 'скорость', 'автомобилист', 'стоянка', 'мвд'],
#  ['сборник', 'раздел', 'палец', 'стих', 'жизнь'],
#  ['команда', 'гонка', 'мерседес', 'феттель', 'пилот'],
#  ['диалектика', 'революция', 'марксизм', 'социализм', 'теория'],
#  ['яблоко', 'человек', 'кампания', 'партия', 'ложь'],
#  ['памятник', 'кремль', 'столица', 'москва', 'спортсмен'],
#  ['япония', 'партия', 'страна', 'год', 'бизнес'],
#  ['воспоминание', 'дума', 'министерство', 'керенский', 'сообщение'],
#  ['отец', 'княжество', 'престол', 'башня', 'сын'],
#  ['оплата', 'карта', 'пассажир', 'проезд', 'автобус'],
#  ['редактор', 'автор', 'текст', 'сайт', 'редактирование'],
#  ['взрыв', 'махачкала', 'следование', 'милиционер', 'автобус'],
#  ['сидельников', 'кремль', 'британия', 'движение', 'рф'],
#  ['кндр', 'сша', 'корея', 'китай', 'саммит'],
#  ['гонка', 'команда', 'пилот', 'алонсо', 'сезон'],
#  ['доля', 'рубль', 'регион', 'область', 'триллион'],
#  ['достоевский', 'писатель', 'михайло', 'россия', 'пётр'],
#  ['словарь', 'язык', 'термин', 'слово', 'понятие'],
#  ['помпео', 'трамп', 'тиллерсон', 'госсекретарь', 'президент'],
#  ['финляндия', 'безопасность', 'сжигание', 'уровень', 'реактор'],
#  ['афганистан', 'боевик', 'иго', 'провинция', 'страна'],
#  ['слуцкий', 'поэт', 'дом', 'стих', 'книга'],
#  ['ходорковский', 'обыск', 'правоохранитель', 'россия', 'акция'],
#  ['питание', 'продукт', 'год', 'россиянин', 'рацион'],
#  ['ранение', 'район', 'данные', 'сержант', 'инспектор'],
#  ['объект', 'вайншток', 'олимпиада', 'козак', 'путин'],
#  ['человек', 'молодая', 'церковь', 'общество', 'качество'],
#  ['удар', 'сирия', 'сила', 'ракета', 'пентагон'],
#  ['блогер', 'спорт', 'россия', 'владимир', 'путин'],
#  ['композиция', 'песнь', 'мэтр', 'хит', 'джаз'],
#  ['компания', 'нефть', 'год', 'страна', 'запас'],
#  ['депутат', 'среда', 'бюллетень', 'заседание', 'выпускник'],
#  ['москва', 'власть', 'ответственность', 'грузия', 'россия'],
#  ['сотрудничество', 'программа', 'гройсман', 'министр', 'кабинет'],
#  ['нии', 'интернат', 'дед', 'партком', 'служба'],
#  ['театр', 'худрук', 'режиссёр', 'бутусов', 'директор'],
#  ['иран', 'саудовец', 'оружие', 'программа', 'бомба'],
#  ['команда', 'пилот', 'гонка', 'подиум', 'росберг'],
#  ['ёлка', 'игрушка', 'коробка', 'ёлочка', 'шар'],
#  ['обвинение', 'прокурор', 'польша', 'катастрофа', 'апрель'],
#  ['страна', 'россия', 'человек', 'общество', 'власть'],
#  ['туркмения', 'телевидение', 'маяк', 'отключение', 'тарелка'],
#  ['греция', 'кредитор', 'ципраса', 'план', 'еврозона'],
#  ['сирия', 'президент', 'боевик', 'рф', 'сша'],
#  ['еаэс', 'соглашение', 'страна', 'услуга', 'цепочка'],
#  ['сера', 'тонна', 'сухогруз', 'пролив', 'экипаж'],
#  ['океан', 'остров', 'доктор', 'море', 'пластик'],
#  ['доказательство', 'фсб', 'россия', 'министр', 'атака'],
#  ['возраст', 'нагрузка', 'экономика', 'год', 'страна'],
#  ['харьков', 'рифма', 'поэт', 'сборник', 'подарок'],
#  ['донбасс', 'украина', 'закон', 'киев', 'комплекс'],
#  ['папа', 'ратцингер', 'кардинал', 'понтифик', 'год'],
#  ['самолёт', 'система', 'бомбардировщик', 'сирия', 'тип'],
#  ['система', 'аппарат', 'боеприпас', 'компания', 'килограмм'],
#  ['старообрядец', 'церковь', 'эстония', 'сотрудничество', 'традиция'],
#  ['интеллект', 'человек', 'функция', 'человечество', 'технология'],
#  ['избирком', 'молодая', 'молодёжь', 'выбор', 'избиратель'],
#  ['корабль', 'проект', 'год', 'вмф', 'программа'],
#  ['авианосец', 'шторм', 'базирование', 'комплекс', 'строительство'],
#  ['поэт', 'стих', 'зима', 'дом', 'круг'],
#  ['режиссёр', 'театр', 'создание', 'сцена', 'шукшин'],
#  ['политика', 'вс', 'россия', 'сирия', 'армия'],
#  ['анкара', 'сша', 'турция', 'вашингтон', 'власть'],
#  ['школа', 'происшествие', 'ребёнок', 'пистолет', 'пострадавший'],
#  ['поставка', 'экспорт', 'нефть', 'год', 'газа'],
#  ['матч', 'шайба', 'команда', 'американец', 'канада'],
#  ['статуя', 'площадь', 'христос', 'москва', 'идея'],
#  ['перевод', 'поэзия', 'проза', 'сутра', 'подвиг'],
#  ['клетка', 'белок', 'самец', 'ген', 'нейрон'],
#  ['кандидат', 'подмосковье', 'яблоко', 'выборы', 'партия'],
#  ['газа', 'украина', 'газопровод', 'миллиард', 'страна'],
#  ['команда', 'пилот', 'трасса', 'гонка', 'авария'],
#  ['поэт', 'поэзия', 'стих', 'стихосложение', 'рифма'],
#  ['масло', 'интернет', 'компьютер', 'машина', 'механик'],
#  ['тиллерсон', 'обвинение', 'глава', 'мид', 'госдеп'],
#  ['американец', 'сша', 'военный', 'генерал', 'сообщение'],
#  ['поток', 'газпром', 'нитка', 'газопровод', 'украина'],
#  ['гонка', 'команда', 'пилот', 'машина', 'подиум'],
#  ['квалификация', 'хонда', 'поул', 'пилот', 'гонка'],
#  ['туркменистан', 'газа', 'год', 'проект', 'месторождение'],
#  ['собака', 'остров', 'мальчик', 'герой', 'режиссёр'],
#  ['оппозиция', 'выбор', 'власть', 'саакашвили', 'движение'],
#  ['год', 'украинец', 'украина', 'показатель', 'ситуация'],
#  ['вода', 'ресурс', 'вод', 'проблема', 'год'],
#  ['женщина', 'обложка', 'выставка', 'журнал', 'мода'],
#  ['мюллер', 'папа', 'кардинал', 'конгрегация', 'префект'],
#  ['самоубийство', 'нея', 'посольство', 'тусовка', 'жизнь'],
#  ['финляндия', 'шайба', 'сборная', 'счёт', 'период'],
#  ['высоцкий', 'январь', 'программа', 'канал', 'первое'],
#  ['терроризм', 'меморандум', 'сша', 'ирак', 'война'],
#  ['препарат', 'лекарство', 'цена', 'год', 'болезнь'],
#  ['самолёт', 'австралия', 'фрагмент', 'рейс', 'тысяча'],
#  ['губернаторов', 'фильтр', 'подпись', 'выбор', 'послание'],
#  ['губернатор', 'чиновник', 'весна', 'рейтинг', 'условие'],
#  ['баронов', 'отделение', 'координатор', 'совет', 'движение'],
#  ['система', 'робот', 'интеллект', 'человек', 'страна'],
#  ['площадка', 'москва', 'город', 'сентябрь', 'столица'],
#  ['страна', 'власть', 'жизнь', 'управление', 'россия'],
#  ['мигрант', 'тысяча', 'гастарбайтер', 'россия', 'рубль'],
#  ['мвф', 'украина', 'год', 'программа', 'реформа'],
#  ['помилование', 'ходорковский', 'юкос', 'дело', 'убийство'],
#  ['смертность', 'рак', 'год', 'курение', 'профилактика'],
#  ['опека', 'газа', 'заседание', 'организация', 'создание'],
#  ['кпрф', 'руководство', 'коммунист', 'митинг', 'активист'],
#  ['москва', 'проект', 'программа', 'жизнь', 'человек'],
#  ['акция', 'яблоко', 'новосибирск', 'партия', 'сторонник'],
#  ['криптовалюта', 'биткоина', 'валюта', 'минфин', 'никифоров'],
#  ['ес', 'брюссель', 'политика', 'правый', 'европа'],
#  ['выброс', 'газ', 'развитие', 'цель', 'соглашение'],
#  ['коваль', 'писатель', 'книга', 'клуб', 'человек'],
#  ['фильм', 'режиссёр', 'фестиваль', 'приз', 'кино'],
#  ['война', 'средство', 'экономика', 'знание', 'безопасность'],
#  ['стандарт', 'васильев', 'источник', 'предмет', 'произведение'],
#  ...]

# %%
evaluate(data['keywords'], keywords_gr)
# Out:
# Precision -  0.19
# Recall -  0.19
# F1 -  0.18
# Jaccard -  0.11

# %% [markdown]
# ##### Лучше, чем исходный вариант с графами.

# %% [markdown]
# ### 4.2 То же самое + заголовки

# %%
for i, t in enumerate(keywords_gr):
    keywords_gr[i] = list(set(keywords_gr[i] + data['title_norm'][i]))

# %%
evaluate(data['keywords'], keywords_gr)
# Out:
# Precision -  0.18
# Recall -  0.24
# F1 -  0.19
# Jaccard -  0.12

# %% [markdown]
# ##### Еще чуть лучше.

# %% [markdown]
# ## 5. Вернем прилагательные

# %%
def normalize(input_text, del_stopwords=True, del_digit=True):
    
    words = [x.lower().strip(string.punctuation+'»«–…') for x in word_tokenize(input_text)]
    words = [morph.parse(x)[0] for x in words if x]
    words = [word.normal_form for word in words if (word.tag.POS in ['NOUN', 'ADJF', 'ADJS']) and ('Name' not in word.tag)] #удалим личные имена

    lemmas = []
    for lemma in words:
        if del_stopwords:
            if lemma in stops:
                continue
        if del_digit:
            if lemma.isdigit():
                continue
        lemmas.append(lemma)
        
    return lemmas

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['content_norm_str'] = data['content_norm'].apply(' '.join)

# %%
tfidf = TfidfVectorizer(ngram_range=(1,1), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}
texts_vectors = tfidf.transform(data['content_norm_str'])
# сортировка по убыванию, поэтому нужно развернуть список
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]] 
keywords[:3]
# Out:
# [['яблоко', 'молодёжный', 'активист', 'акция', 'ставропольский'],
#  ['куб', 'газпром', 'газа', 'миллиард', 'добыча'],
#  ['книга', 'жанр', 'роман', 'стихотворение', 'читатель']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.18
# Recall -  0.18
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# ##### Лучше исходного

# %% [markdown]
# ### 5.1 То же самое + заголовки

# %%
data['titles_norm'] = data['title'].apply(normalize)

# %%
for i, t in enumerate(keywords):
    keywords[i] = list(set(keywords[i] + data['title_norm'][i]))

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.17
# Recall -  0.23
# F1 -  0.18
# Jaccard -  0.11

# %% [markdown]
# ##### Еще чуть лучше
